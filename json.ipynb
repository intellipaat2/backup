# %%
import numpy as np
from sklearn.datasets import make_blobs

import urllib
import json
import datetime
import calendar
from os import path
from collections import Counter

JSON_FILE = 'weather.json'

if not path.exists(JSON_FILE):
    data_url = 'https://data.townofcary.org/api/v2/catalog/datasets/rdu-weather-history/exports/json'

    urllib.request.urlretrieve(data_url, JSON_FILE)

f = open(JSON_FILE, 'r')
lines = f.readlines()
f.close()
json_data = ''.join(lines)

weather = json.loads(json_data)


weather_by_date = {}

for day in weather:
    dt = datetime.datetime.strptime(day['date'], '%Y-%m-%d')
    if dt.year < 2019:
        if not dt.year in list(weather_by_date.keys()):
            weather_by_date[dt.year] = {}
        if not dt.month in weather_by_date[dt.year].keys():
            weather_by_date[dt.year][dt.month] = []
        weather_by_date[dt.year][dt.month].append(day)
    
flatten = lambda l: [item for sublist in l for item in sublist]

MONTHS = np.array([calendar.month_abbr[m] for m in (np.arange(12) + 1)])

def monthly_data_by_key(month=1, key='precipitation'):
    monthly_data = flatten([weather_by_date[year][month] for year in weather_by_date.keys()])
    return [day[key] for day in monthly_data]

def data_by_key(year=2018, key='precipitation'):
    return flatten([weather_by_date[year][month] for month in np.arange(1, 13)])

def monthly_data_values_by_key(month=1, key='precipitation'):
    monthly_data = flatten([weather_by_date[year][month] for year in weather_by_date.keys()])
    return [day[key] for day in monthly_data]

def monthly_freq_counts(month=1, key='precipitation'):
    data = np.array(monthly_data_by_key(month=month, key=key))
    l_bound = np.min(data)
    u_bound = np.max(data)
    intervals = np.linspace(l_bound, u_bound, 11)
    freq = Counter()
    
    for point in data:
        for index, interval in enumerate(intervals):
            if point < interval:
                freq[index] += 1
                break
    
    return [freq[key] for key in sorted(freq.keys())]

def precip_sums_for_year(year=2018):
    if year not in sorted(list(weather_by_date.keys())):
        raise IndexError('Invalid year')
        weather_for_year = weather_by_date[year]
        return sorted(zip(weather_for_year.keys(), [sum([day['precipitation'] for day in weather_for_year[month]]) for month in weather_for_year.keys()]))

def temps_by_month_for_year(year=2018):
    if year not in sorted(list(weather_by_date.keys())):
        raise IndexError('Invalid year')
    the_weather = weather_by_date[year]
    the_weather = dict(zip(sorted(the_weather.keys()), [[day['temperaturemax'] for day in the_weather[month]]  for month in sorted(the_weather.keys())]))
    for key in the_weather.keys():
        if len(the_weather[key] < 31):
            the_weather[key]
    

def get_wind_points():
    avg_wind = monthly_data_by_key(month=1, key='avgwindspeed')
    fast_wind = monthly_data_by_key(month=1, key='fastest5secwindspeed')
    
    points = list(zip(avg_wind, fast_wind))
    points = np.array([point for point in points if point[0] is not None and point[1] is not None])
    for _ in range(5):
        mindex = np.argmax(points[:,1])
        points = np.delete(points, mindex, 0)
    return points

def get_blobs():
    return make_blobs(n_samples=200, centers=5)

def get_normal_counts(n_samples=10000):
    data = np.random.randn(n_samples)
    freq = Counter()
    
    l_bound = np.min(data)
    u_bound = np.max(data)
    intervals = np.linspace(l_bound, u_bound, 21)
    
    for point in data:
        for index, interval in enumerate(intervals):
            if point < interval:
                freq[index] += 1
                break
                
    return [freq[key] for key in sorted(freq.keys())]

# %%
weather
# Out:
# [{'date': '2017-01-04',
#   'tmin': 41,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-01-12',
#   'tmin': 54,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 12.53},
#  {'date': '2017-01-17',
#   'tmin': 47,
#   'tmax': 62,
#   'prcp': 0.04,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2017-01-27',
#   'tmin': 30,
#   'tmax': 51,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2017-01-29',
#   'tmin': 30,
#   'tmax': 54,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2017-01-31',
#   'tmin': 31,
#   'tmax': 68,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 12.75},
#  {'date': '2017-02-01',
#   'tmin': 42,
#   'tmax': 70,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2017-02-13',
#   'tmin': 37,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2017-02-15',
#   'tmin': 39,
#   'tmax': 56,
#   'prcp': 0.34,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2017-02-17',
#   'tmin': 34,
#   'tmax': 66,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2017-03-14',
#   'tmin': 30,
#   'tmax': 54,
#   'prcp': 0.25,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.51},
#  {'date': '2017-03-19',
#   'tmin': 36,
#   'tmax': 57,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2017-03-21',
#   'tmin': 50,
#   'tmax': 82,
#   'prcp': 0.2,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-03-27',
#   'tmin': 59,
#   'tmax': 79,
#   'prcp': 0.06,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2017-03-30',
#   'tmin': 55,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.95},
#  {'date': '2017-03-31',
#   'tmin': 58,
#   'tmax': 79,
#   'prcp': 0.42,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.74},
#  {'date': '2017-04-12',
#   'tmin': 56,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2017-04-19',
#   'tmin': 55,
#   'tmax': 69,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2017-04-26',
#   'tmin': 56,
#   'tmax': 81,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2017-04-27',
#   'tmin': 62,
#   'tmax': 82,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.51},
#  {'date': '2017-04-29',
#   'tmin': 72,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.07},
#  {'date': '2017-04-30',
#   'tmin': 70,
#   'tmax': 86,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.51},
#  {'date': '2017-05-05',
#   'tmin': 56,
#   'tmax': 78,
#   'prcp': 1.48,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 15.88},
#  {'date': '2017-05-14',
#   'tmin': 49,
#   'tmax': 81,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2017-05-16',
#   'tmin': 57,
#   'tmax': 87,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2017-05-27',
#   'tmin': 61,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2017-05-31',
#   'tmin': 68,
#   'tmax': 86,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2017-06-07',
#   'tmin': 59,
#   'tmax': 77,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.29},
#  {'date': '2017-06-19',
#   'tmin': 70,
#   'tmax': 92,
#   'prcp': 0.09,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.86},
#  {'date': '2017-06-24',
#   'tmin': 71,
#   'tmax': 91,
#   'prcp': 0.46,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.83},
#  {'date': '2017-06-26',
#   'tmin': 60,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2017-06-29',
#   'tmin': 60,
#   'tmax': 87,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2017-07-01',
#   'tmin': 73,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2017-07-03',
#   'tmin': 70,
#   'tmax': 93,
#   'prcp': 0.15,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2017-07-07',
#   'tmin': 73,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.95},
#  {'date': '2017-07-09',
#   'tmin': 69,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2017-07-21',
#   'tmin': 74,
#   'tmax': 98,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2017-07-24',
#   'tmin': 71,
#   'tmax': 93,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2017-07-31',
#   'tmin': 58,
#   'tmax': 87,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2017-08-02',
#   'tmin': 66,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2017-08-05',
#   'tmin': 68,
#   'tmax': 92,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2017-08-12',
#   'tmin': 73,
#   'tmax': 92,
#   'prcp': 0.48,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2017-08-29',
#   'tmin': 64,
#   'tmax': 71,
#   'prcp': 0.22,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.5},
#  {'date': '2017-09-07',
#   'tmin': 53,
#   'tmax': 76,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2017-09-10',
#   'tmin': 51,
#   'tmax': 71,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.95},
#  {'date': '2017-09-12',
#   'tmin': 63,
#   'tmax': 79,
#   'prcp': 0.63,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.74},
#  {'date': '2017-09-19',
#   'tmin': 64,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2017-09-26',
#   'tmin': 69,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2017-09-27',
#   'tmin': 68,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2017-10-01',
#   'tmin': 48,
#   'tmax': 71,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2017-10-07',
#   'tmin': 59,
#   'tmax': 86,
#   'prcp': 0.15,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.26},
#  {'date': '2017-10-16',
#   'tmin': 51,
#   'tmax': 69,
#   'prcp': 0.25,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-10-22',
#   'tmin': 51,
#   'tmax': 79,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2017-10-27',
#   'tmin': 38,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-11-01',
#   'tmin': 46,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2017-11-07',
#   'tmin': 44,
#   'tmax': 63,
#   'prcp': 0.1,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2017-11-12',
#   'tmin': 28,
#   'tmax': 49,
#   'prcp': 0.03,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.57},
#  {'date': '2017-11-15',
#   'tmin': 33,
#   'tmax': 54,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2017-11-17',
#   'tmin': 34,
#   'tmax': 57,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2017-11-21',
#   'tmin': 30,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2017-11-27',
#   'tmin': 26,
#   'tmax': 61,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.34},
#  {'date': '2017-12-09',
#   'tmin': 32,
#   'tmax': 34,
#   'prcp': 0.3,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-12-11',
#   'tmin': 26,
#   'tmax': 55,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2017-12-13',
#   'tmin': 21,
#   'tmax': 43,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.72},
#  {'date': '2017-01-03',
#   'tmin': 47,
#   'tmax': 56,
#   'prcp': 0.31,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2017-12-16',
#   'tmin': 24,
#   'tmax': 50,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2017-01-07',
#   'tmin': 20,
#   'tmax': 32,
#   'prcp': 0.6,
#   'snow': 0.5,
#   'snwd': 0.0,
#   'awnd': 9.62},
#  {'date': '2017-12-19',
#   'tmin': 36,
#   'tmax': 70,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2017-01-10',
#   'tmin': 24,
#   'tmax': 48,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 1.2,
#   'awnd': 5.14},
#  {'date': '2017-12-21',
#   'tmin': 36,
#   'tmax': 53,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2017-01-13',
#   'tmin': 50,
#   'tmax': 76,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2017-12-24',
#   'tmin': 43,
#   'tmax': 61,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2017-01-15',
#   'tmin': 40,
#   'tmax': 57,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-12-27',
#   'tmin': 27,
#   'tmax': 45,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2017-01-18',
#   'tmin': 45,
#   'tmax': 70,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2017-12-31',
#   'tmin': 23,
#   'tmax': 35,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.07},
#  {'date': '2017-01-21',
#   'tmin': 51,
#   'tmax': 55,
#   'prcp': 0.38,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2018-01-05',
#   'tmin': 12,
#   'tmax': 31,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2017-01-25',
#   'tmin': 36,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2018-01-13',
#   'tmin': 29,
#   'tmax': 56,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.62},
#  {'date': '2017-01-28',
#   'tmin': 27,
#   'tmax': 52,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.4},
#  {'date': '2018-01-15',
#   'tmin': 17,
#   'tmax': 39,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2017-02-09',
#   'tmin': 32,
#   'tmax': 60,
#   'prcp': 0.11,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.96},
#  {'date': '2018-01-16',
#   'tmin': 20,
#   'tmax': 47,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.79},
#  {'date': '2017-02-18',
#   'tmin': 37,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2018-01-18',
#   'tmin': 10,
#   'tmax': 34,
#   'prcp': 0.0,
#   'snow': 0.2,
#   'snwd': 5.9,
#   'awnd': 5.59},
#  {'date': '2017-02-19',
#   'tmin': 44,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2018-01-22',
#   'tmin': 38,
#   'tmax': 62,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2017-02-20',
#   'tmin': 42,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.79},
#  {'date': '2018-02-04',
#   'tmin': 33,
#   'tmax': 56,
#   'prcp': 0.61,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2017-02-23',
#   'tmin': 50,
#   'tmax': 77,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2018-03-01',
#   'tmin': 50,
#   'tmax': 57,
#   'prcp': 0.59,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2017-02-28',
#   'tmin': 50,
#   'tmax': 77,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2018-03-06',
#   'tmin': 32,
#   'tmax': 42,
#   'prcp': 0.45,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2017-03-04',
#   'tmin': 25,
#   'tmax': 54,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.46},
#  {'date': '2018-03-15',
#   'tmin': 24,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.63},
#  {'date': '2017-03-07',
#   'tmin': 49,
#   'tmax': 74,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 13.87},
#  {'date': '2018-03-16',
#   'tmin': 39,
#   'tmax': 68,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-03-09',
#   'tmin': 37,
#   'tmax': 75,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2018-03-18',
#   'tmin': 40,
#   'tmax': 60,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2017-03-10',
#   'tmin': 41,
#   'tmax': 69,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.74},
#  {'date': '2018-03-19',
#   'tmin': 44,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2017-03-11',
#   'tmin': 31,
#   'tmax': 50,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2018-03-21',
#   'tmin': 32,
#   'tmax': 42,
#   'prcp': 0.05,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2017-03-26',
#   'tmin': 52,
#   'tmax': 77,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2018-03-26',
#   'tmin': 32,
#   'tmax': 53,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.29},
#  {'date': '2017-03-28',
#   'tmin': 60,
#   'tmax': 80,
#   'prcp': 0.06,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2018-03-28',
#   'tmin': 43,
#   'tmax': 76,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.74},
#  {'date': '2017-04-08',
#   'tmin': 34,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2018-04-02',
#   'tmin': 51,
#   'tmax': 81,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.84},
#  {'date': '2017-04-22',
#   'tmin': 56,
#   'tmax': 87,
#   'prcp': 0.09,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.4},
#  {'date': '2018-04-05',
#   'tmin': 34,
#   'tmax': 61,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2017-04-23',
#   'tmin': 53,
#   'tmax': 56,
#   'prcp': 0.77,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.18},
#  {'date': '2018-04-07',
#   'tmin': 33,
#   'tmax': 62,
#   'prcp': 0.99,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2017-04-28',
#   'tmin': 69,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2018-04-17',
#   'tmin': 33,
#   'tmax': 62,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.4},
#  {'date': '2017-05-03',
#   'tmin': 53,
#   'tmax': 79,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2018-04-29',
#   'tmin': 44,
#   'tmax': 66,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-05-04',
#   'tmin': 57,
#   'tmax': 80,
#   'prcp': 0.29,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.74},
#  {'date': '2018-04-30',
#   'tmin': 36,
#   'tmax': 72,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2017-05-06',
#   'tmin': 53,
#   'tmax': 67,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.96},
#  {'date': '2018-05-10',
#   'tmin': 59,
#   'tmax': 87,
#   'prcp': 0.18,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2017-05-09',
#   'tmin': 43,
#   'tmax': 64,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.79},
#  {'date': '2018-05-15',
#   'tmin': 69,
#   'tmax': 88,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.72},
#  {'date': '2017-05-17',
#   'tmin': 66,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.95},
#  {'date': '2018-05-16',
#   'tmin': 68,
#   'tmax': 85,
#   'prcp': 0.76,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2017-05-21',
#   'tmin': 60,
#   'tmax': 76,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2018-05-19',
#   'tmin': 69,
#   'tmax': 75,
#   'prcp': 0.59,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.5},
#  {'date': '2017-06-06',
#   'tmin': 64,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2018-05-31',
#   'tmin': 71,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2017-06-08',
#   'tmin': 55,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2018-06-04',
#   'tmin': 64,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2017-06-09',
#   'tmin': 53,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-06-09',
#   'tmin': 68,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.68},
#  {'date': '2017-06-13',
#   'tmin': 67,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2018-06-19',
#   'tmin': 73,
#   'tmax': 96,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2017-06-17',
#   'tmin': 72,
#   'tmax': 86,
#   'prcp': 0.21,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2018-06-22',
#   'tmin': 71,
#   'tmax': 95,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2017-06-22',
#   'tmin': 71,
#   'tmax': 84,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2018-06-23',
#   'tmin': 74,
#   'tmax': 92,
#   'prcp': 0.18,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.72},
#  {'date': '2017-06-23',
#   'tmin': 73,
#   'tmax': 91,
#   'prcp': 0.04,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 13.65},
#  {'date': '2018-06-27',
#   'tmin': 65,
#   'tmax': 86,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2017-06-27',
#   'tmin': 59,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2018-06-29',
#   'tmin': 70,
#   'tmax': 92,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2017-07-04',
#   'tmin': 71,
#   'tmax': 92,
#   'prcp': 0.84,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2018-07-03',
#   'tmin': 75,
#   'tmax': 95,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2017-07-15',
#   'tmin': 75,
#   'tmax': 94,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2018-07-11',
#   'tmin': 67,
#   'tmax': 96,
#   'prcp': 0.05,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2017-07-23',
#   'tmin': 71,
#   'tmax': 102,
#   'prcp': 0.56,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.95},
#  {'date': '2018-07-12',
#   'tmin': 72,
#   'tmax': 87,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2017-07-27',
#   'tmin': 72,
#   'tmax': 94,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2018-08-05',
#   'tmin': 72,
#   'tmax': 93,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2017-08-08',
#   'tmin': 68,
#   'tmax': 78,
#   'prcp': 1.5,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2018-08-11',
#   'tmin': 72,
#   'tmax': 91,
#   'prcp': 0.04,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2017-08-10',
#   'tmin': 63,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-08-17',
#   'tmin': 73,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.62},
#  {'date': '2017-08-16',
#   'tmin': 74,
#   'tmax': 92,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-08-23',
#   'tmin': 60,
#   'tmax': 80,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2017-08-17',
#   'tmin': 75,
#   'tmax': 94,
#   'prcp': 0.24,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2018-08-28',
#   'tmin': 71,
#   'tmax': 94,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2017-08-22',
#   'tmin': 74,
#   'tmax': 96,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2018-08-30',
#   'tmin': 73,
#   'tmax': 95,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2017-08-25',
#   'tmin': 68,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2018-09-01',
#   'tmin': 71,
#   'tmax': 93,
#   'prcp': 0.19,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2017-09-03',
#   'tmin': 62,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2018-09-12',
#   'tmin': 72,
#   'tmax': 88,
#   'prcp': 0.13,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2017-09-14',
#   'tmin': 64,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2018-09-17',
#   'tmin': 72,
#   'tmax': 88,
#   'prcp': 1.32,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.63},
#  {'date': '2017-09-15',
#   'tmin': 63,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.79},
#  {'date': '2018-09-21',
#   'tmin': 70,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2017-09-16',
#   'tmin': 62,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2018-09-23',
#   'tmin': 64,
#   'tmax': 76,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2017-09-17',
#   'tmin': 63,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2018-09-24',
#   'tmin': 64,
#   'tmax': 74,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-09-21',
#   'tmin': 65,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.79},
#  {'date': '2018-09-29',
#   'tmin': 60,
#   'tmax': 82,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2017-09-23',
#   'tmin': 61,
#   'tmax': 87,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2018-10-02',
#   'tmin': 61,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2017-09-24',
#   'tmin': 63,
#   'tmax': 87,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2018-10-05',
#   'tmin': 68,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2017-09-29',
#   'tmin': 60,
#   'tmax': 72,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2018-10-06',
#   'tmin': 68,
#   'tmax': 82,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2017-09-30',
#   'tmin': 54,
#   'tmax': 77,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.83},
#  {'date': '2018-10-19',
#   'tmin': 39,
#   'tmax': 69,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2017-10-04',
#   'tmin': 50,
#   'tmax': 82,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.24},
#  {'date': '2018-10-28',
#   'tmin': 42,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.5},
#  {'date': '2017-10-05',
#   'tmin': 54,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2018-10-31',
#   'tmin': 42,
#   'tmax': 72,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.5},
#  {'date': '2017-10-08',
#   'tmin': 74,
#   'tmax': 84,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2018-11-03',
#   'tmin': 39,
#   'tmax': 61,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2017-10-09',
#   'tmin': 74,
#   'tmax': 92,
#   'prcp': 0.09,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.86},
#  {'date': '2018-11-07',
#   'tmin': 49,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.34},
#  {'date': '2017-10-10',
#   'tmin': 75,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2018-11-11',
#   'tmin': 28,
#   'tmax': 51,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2017-10-17',
#   'tmin': 42,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2018-11-17',
#   'tmin': 33,
#   'tmax': 59,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.57},
#  {'date': '2017-10-18',
#   'tmin': 37,
#   'tmax': 68,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.68},
#  {'date': '2018-11-30',
#   'tmin': 42,
#   'tmax': 68,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.72},
#  {'date': '2017-10-19',
#   'tmin': 42,
#   'tmax': 76,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.12},
#  {'date': '2018-12-21',
#   'tmin': 46,
#   'tmax': 65,
#   'prcp': 0.04,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 14.99},
#  {'date': '2017-11-03',
#   'tmin': 52,
#   'tmax': 81,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.01},
#  {'date': '2018-12-24',
#   'tmin': 29,
#   'tmax': 51,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2017-11-11',
#   'tmin': 28,
#   'tmax': 46,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2018-12-27',
#   'tmin': 29,
#   'tmax': 54,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2017-11-16',
#   'tmin': 36,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2018-12-31',
#   'tmin': 47,
#   'tmax': 67,
#   'prcp': 0.13,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2017-11-25',
#   'tmin': 29,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2019-01-01',
#   'tmin': 51,
#   'tmax': 71,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2017-11-28',
#   'tmin': 29,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.24},
#  {'date': '2019-01-03',
#   'tmin': 47,
#   'tmax': 55,
#   'prcp': 0.21,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.68},
#  {'date': '2017-12-02',
#   'tmin': 45,
#   'tmax': 51,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2019-01-08',
#   'tmin': 46,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2017-12-05',
#   'tmin': 41,
#   'tmax': 69,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2019-01-13',
#   'tmin': 32,
#   'tmax': 37,
#   'prcp': 1.04,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2017-12-06',
#   'tmin': 41,
#   'tmax': 57,
#   'prcp': 0.24,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2019-01-15',
#   'tmin': 28,
#   'tmax': 47,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.34},
#  {'date': '2017-12-08',
#   'tmin': 32,
#   'tmax': 43,
#   'prcp': 1.33,
#   'snow': 0.3,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-01-19',
#   'tmin': 37,
#   'tmax': 59,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2017-12-10',
#   'tmin': 27,
#   'tmax': 43,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-01-23',
#   'tmin': 31,
#   'tmax': 64,
#   'prcp': 0.04,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.83},
#  {'date': '2017-12-17',
#   'tmin': 27,
#   'tmax': 51,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.24},
#  {'date': '2019-02-06',
#   'tmin': 47,
#   'tmax': 77,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2018-01-03',
#   'tmin': 9,
#   'tmax': 32,
#   'prcp': 0.06,
#   'snow': 0.9,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2019-02-08',
#   'tmin': 45,
#   'tmax': 75,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2018-01-08',
#   'tmin': 16,
#   'tmax': 47,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2019-02-27',
#   'tmin': 40,
#   'tmax': 50,
#   'prcp': 0.29,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2018-01-11',
#   'tmin': 41,
#   'tmax': 64,
#   'prcp': 0.11,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2019-02-28',
#   'tmin': 42,
#   'tmax': 62,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2018-01-12',
#   'tmin': 56,
#   'tmax': 71,
#   'prcp': 0.5,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.41},
#  {'date': '2019-03-07',
#   'tmin': 23,
#   'tmax': 50,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.46},
#  {'date': '2018-01-25',
#   'tmin': 26,
#   'tmax': 49,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2019-03-08',
#   'tmin': 39,
#   'tmax': 49,
#   'prcp': 0.1,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2018-01-26',
#   'tmin': 25,
#   'tmax': 57,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2019-03-22',
#   'tmin': 42,
#   'tmax': 63,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.4},
#  {'date': '2018-02-02',
#   'tmin': 24,
#   'tmax': 57,
#   'prcp': 0.16,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.83},
#  {'date': '2019-03-27',
#   'tmin': 30,
#   'tmax': 57,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2018-02-05',
#   'tmin': 29,
#   'tmax': 48,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2019-03-28',
#   'tmin': 32,
#   'tmax': 66,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2018-02-10',
#   'tmin': 43,
#   'tmax': 65,
#   'prcp': 0.08,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2019-04-03',
#   'tmin': 31,
#   'tmax': 69,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2018-02-11',
#   'tmin': 64,
#   'tmax': 72,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 14.99},
#  {'date': '2019-04-08',
#   'tmin': 57,
#   'tmax': 81,
#   'prcp': 1.98,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.5},
#  {'date': '2018-02-14',
#   'tmin': 37,
#   'tmax': 58,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2019-04-09',
#   'tmin': 61,
#   'tmax': 74,
#   'prcp': 0.04,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2018-02-18',
#   'tmin': 39,
#   'tmax': 61,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2019-04-11',
#   'tmin': 47,
#   'tmax': 79,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2018-02-23',
#   'tmin': 52,
#   'tmax': 70,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2019-04-12',
#   'tmin': 59,
#   'tmax': 69,
#   'prcp': 0.65,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2018-02-24',
#   'tmin': 57,
#   'tmax': 78,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.18},
#  {'date': '2019-04-22',
#   'tmin': 43,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.79},
#  {'date': '2018-02-26',
#   'tmin': 40,
#   'tmax': 63,
#   'prcp': 0.09,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2019-04-23',
#   'tmin': 46,
#   'tmax': 81,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2018-02-27',
#   'tmin': 35,
#   'tmax': 61,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.24},
#  {'date': '2019-04-30',
#   'tmin': 60,
#   'tmax': 86,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.5},
#  {'date': '2018-03-04',
#   'tmin': 35,
#   'tmax': 56,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2019-05-03',
#   'tmin': 63,
#   'tmax': 84,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2018-03-05',
#   'tmin': 26,
#   'tmax': 54,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2019-05-08',
#   'tmin': 62,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2018-03-07',
#   'tmin': 35,
#   'tmax': 54,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2019-05-10',
#   'tmin': 66,
#   'tmax': 78,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2018-03-08',
#   'tmin': 27,
#   'tmax': 47,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2019-05-11',
#   'tmin': 64,
#   'tmax': 81,
#   'prcp': 0.18,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2018-03-09',
#   'tmin': 25,
#   'tmax': 52,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2019-05-14',
#   'tmin': 47,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2018-03-10',
#   'tmin': 38,
#   'tmax': 56,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2019-05-16',
#   'tmin': 51,
#   'tmax': 79,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-03-11',
#   'tmin': 38,
#   'tmax': 49,
#   'prcp': 0.21,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.83},
#  {'date': '2019-05-21',
#   'tmin': 63,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2018-03-23',
#   'tmin': 27,
#   'tmax': 56,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2019-06-12',
#   'tmin': 59,
#   'tmax': 74,
#   'prcp': 0.35,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2018-03-27',
#   'tmin': 34,
#   'tmax': 49,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2019-06-14',
#   'tmin': 53,
#   'tmax': 79,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-03-29',
#   'tmin': 56,
#   'tmax': 80,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 13.87},
#  {'date': '2019-06-28',
#   'tmin': 70,
#   'tmax': 97,
#   'prcp': 1.09,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2018-04-03',
#   'tmin': 45,
#   'tmax': 75,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2019-06-30',
#   'tmin': 69,
#   'tmax': 94,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2018-04-06',
#   'tmin': 45,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.41},
#  {'date': '2019-07-03',
#   'tmin': 70,
#   'tmax': 97,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-04-14',
#   'tmin': 59,
#   'tmax': 81,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 13.87},
#  {'date': '2019-07-07',
#   'tmin': 75,
#   'tmax': 93,
#   'prcp': 0.21,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2018-04-18',
#   'tmin': 42,
#   'tmax': 82,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.62},
#  {'date': '2019-07-11',
#   'tmin': 75,
#   'tmax': 93,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2018-04-24',
#   'tmin': 53,
#   'tmax': 65,
#   'prcp': 0.85,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 12.3},
#  {'date': '2019-07-14',
#   'tmin': 72,
#   'tmax': 96,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2018-05-02',
#   'tmin': 53,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.07},
#  {'date': '2019-07-15',
#   'tmin': 70,
#   'tmax': 95,
#   'prcp': 0.35,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2018-05-04',
#   'tmin': 60,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 12.97},
#  {'date': '2019-07-17',
#   'tmin': 76,
#   'tmax': 98,
#   'prcp': 0.03,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.95},
#  {'date': '2018-05-06',
#   'tmin': 62,
#   'tmax': 85,
#   'prcp': 0.16,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2019-07-19',
#   'tmin': 74,
#   'tmax': 98,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2018-05-07',
#   'tmin': 55,
#   'tmax': 74,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2019-07-21',
#   'tmin': 73,
#   'tmax': 99,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.62},
#  {'date': '2018-05-17',
#   'tmin': 69,
#   'tmax': 77,
#   'prcp': 0.69,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2019-07-24',
#   'tmin': 62,
#   'tmax': 84,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2018-05-23',
#   'tmin': 69,
#   'tmax': 87,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2019-07-25',
#   'tmin': 63,
#   'tmax': 87,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2018-06-01',
#   'tmin': 69,
#   'tmax': 92,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2019-07-30',
#   'tmin': 68,
#   'tmax': 94,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.26},
#  {'date': '2018-06-08',
#   'tmin': 65,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2019-08-02',
#   'tmin': 68,
#   'tmax': 87,
#   'prcp': 0.21,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2018-06-11',
#   'tmin': 64,
#   'tmax': 85,
#   'prcp': 0.31,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.72},
#  {'date': '2019-08-10',
#   'tmin': 71,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2018-06-21',
#   'tmin': 72,
#   'tmax': 92,
#   'prcp': 0.12,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2019-08-16',
#   'tmin': 70,
#   'tmax': 88,
#   'prcp': 0.64,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2018-06-25',
#   'tmin': 72,
#   'tmax': 88,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2019-08-17',
#   'tmin': 72,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2018-06-30',
#   'tmin': 71,
#   'tmax': 94,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2019-08-19',
#   'tmin': 72,
#   'tmax': 95,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.26},
#  {'date': '2018-07-05',
#   'tmin': 72,
#   'tmax': 95,
#   'prcp': 0.03,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2019-08-28',
#   'tmin': 69,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2018-07-14',
#   'tmin': 65,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2019-09-01',
#   'tmin': 63,
#   'tmax': 86,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2018-07-17',
#   'tmin': 72,
#   'tmax': 98,
#   'prcp': 0.1,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.5},
#  {'date': '2019-09-10',
#   'tmin': 70,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2018-07-20',
#   'tmin': 69,
#   'tmax': 86,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.4},
#  {'date': '2019-09-12',
#   'tmin': 71,
#   'tmax': 96,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-07-27',
#   'tmin': 73,
#   'tmax': 95,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2019-09-13',
#   'tmin': 71,
#   'tmax': 82,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.95},
#  {'date': '2018-08-03',
#   'tmin': 70,
#   'tmax': 77,
#   'prcp': 1.12,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-09-17',
#   'tmin': 66,
#   'tmax': 88,
#   'prcp': 0.07,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2018-08-08',
#   'tmin': 69,
#   'tmax': 94,
#   'prcp': 0.46,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2019-09-18',
#   'tmin': 60,
#   'tmax': 79,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2018-08-14',
#   'tmin': 65,
#   'tmax': 86,
#   'prcp': 0.12,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.46},
#  {'date': '2019-09-30',
#   'tmin': 71,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2018-08-15',
#   'tmin': 68,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.24},
#  {'date': '2019-10-12',
#   'tmin': 52,
#   'tmax': 86,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-08-18',
#   'tmin': 73,
#   'tmax': 88,
#   'prcp': 0.49,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.84},
#  {'date': '2019-10-22',
#   'tmin': 57,
#   'tmax': 77,
#   'prcp': 0.18,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2018-08-22',
#   'tmin': 70,
#   'tmax': 88,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2019-11-30',
#   'tmin': 46,
#   'tmax': 50,
#   'prcp': 0.25,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-09-02',
#   'tmin': 69,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.24},
#  {'date': '2019-12-11',
#   'tmin': 30,
#   'tmax': 48,
#   'prcp': 0.32,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2018-09-04',
#   'tmin': 72,
#   'tmax': 92,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2019-12-16',
#   'tmin': 40,
#   'tmax': 70,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2018-09-16',
#   'tmin': 73,
#   'tmax': 76,
#   'prcp': 0.9,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 14.99},
#  {'date': '2019-12-18',
#   'tmin': 34,
#   'tmax': 48,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.26},
#  {'date': '2018-09-18',
#   'tmin': 71,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2019-12-19',
#   'tmin': 27,
#   'tmax': 44,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.79},
#  {'date': '2018-10-16',
#   'tmin': 64,
#   'tmax': 75,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2019-12-23',
#   'tmin': 42,
#   'tmax': 50,
#   'prcp': 0.25,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2018-10-20',
#   'tmin': 54,
#   'tmax': 67,
#   'prcp': 0.21,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2019-12-27',
#   'tmin': 44,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.01},
#  {'date': '2018-10-21',
#   'tmin': 37,
#   'tmax': 58,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2019-12-31',
#   'tmin': 39,
#   'tmax': 59,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2018-10-26',
#   'tmin': 42,
#   'tmax': 52,
#   'prcp': 1.58,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2020-01-01',
#   'tmin': 35,
#   'tmax': 55,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2018-10-29',
#   'tmin': 39,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2020-01-11',
#   'tmin': 57,
#   'tmax': 72,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 12.97},
#  {'date': '2018-10-30',
#   'tmin': 35,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.12},
#  {'date': '2020-01-12',
#   'tmin': 63,
#   'tmax': 70,
#   'prcp': 0.31,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2018-11-12',
#   'tmin': 35,
#   'tmax': 48,
#   'prcp': 3.17,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2020-01-26',
#   'tmin': 32,
#   'tmax': 54,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2018-11-13',
#   'tmin': 44,
#   'tmax': 51,
#   'prcp': 1.19,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2020-01-29',
#   'tmin': 28,
#   'tmax': 50,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.68},
#  {'date': '2018-11-15',
#   'tmin': 36,
#   'tmax': 43,
#   'prcp': 0.88,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.29},
#  {'date': '2020-01-30',
#   'tmin': 32,
#   'tmax': 51,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2018-11-18',
#   'tmin': 37,
#   'tmax': 59,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.57},
#  {'date': '2020-02-02',
#   'tmin': 33,
#   'tmax': 63,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.96},
#  {'date': '2018-11-19',
#   'tmin': 43,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2020-02-04',
#   'tmin': 57,
#   'tmax': 69,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.07},
#  {'date': '2018-11-23',
#   'tmin': 27,
#   'tmax': 45,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.83},
#  {'date': '2020-02-08',
#   'tmin': 27,
#   'tmax': 43,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2018-11-26',
#   'tmin': 39,
#   'tmax': 63,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.84},
#  {'date': '2020-02-21',
#   'tmin': 26,
#   'tmax': 36,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 2.0,
#   'awnd': 7.61},
#  {'date': '2018-12-04',
#   'tmin': 41,
#   'tmax': 53,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2020-02-22',
#   'tmin': 22,
#   'tmax': 54,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.68},
#  {'date': '2018-12-06',
#   'tmin': 25,
#   'tmax': 46,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2020-02-26',
#   'tmin': 48,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2018-12-18',
#   'tmin': 34,
#   'tmax': 53,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.01},
#  {'date': '2020-03-01',
#   'tmin': 24,
#   'tmax': 59,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2018-12-28',
#   'tmin': 50,
#   'tmax': 68,
#   'prcp': 1.61,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.84},
#  {'date': '2020-03-06',
#   'tmin': 40,
#   'tmax': 59,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.83},
#  {'date': '2019-01-02',
#   'tmin': 47,
#   'tmax': 54,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2020-03-14',
#   'tmin': 51,
#   'tmax': 69,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2019-01-04',
#   'tmin': 46,
#   'tmax': 60,
#   'prcp': 0.54,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2020-03-17',
#   'tmin': 50,
#   'tmax': 63,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2019-01-09',
#   'tmin': 37,
#   'tmax': 57,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.4},
#  {'date': '2020-03-22',
#   'tmin': 46,
#   'tmax': 58,
#   'prcp': 0.03,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.96},
#  {'date': '2019-01-20',
#   'tmin': 26,
#   'tmax': 59,
#   'prcp': 0.61,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 12.3},
#  {'date': '2020-04-06',
#   'tmin': 52,
#   'tmax': 82,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2019-01-26',
#   'tmin': 22,
#   'tmax': 51,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.46},
#  {'date': '2020-04-10',
#   'tmin': 42,
#   'tmax': 60,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2019-01-27',
#   'tmin': 26,
#   'tmax': 53,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2020-04-18',
#   'tmin': 41,
#   'tmax': 67,
#   'prcp': 0.36,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2019-01-30',
#   'tmin': 21,
#   'tmax': 44,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2020-04-29',
#   'tmin': 59,
#   'tmax': 81,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 15.21},
#  {'date': '2019-02-01',
#   'tmin': 27,
#   'tmax': 58,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2020-05-03',
#   'tmin': 53,
#   'tmax': 86,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.17},
#  {'date': '2019-02-05',
#   'tmin': 38,
#   'tmax': 76,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.57},
#  {'date': '2020-05-05',
#   'tmin': 53,
#   'tmax': 73,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2019-02-07',
#   'tmin': 60,
#   'tmax': 79,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 12.75},
#  {'date': '2020-05-23',
#   'tmin': 61,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2019-02-12',
#   'tmin': 41,
#   'tmax': 48,
#   'prcp': 0.17,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2020-05-28',
#   'tmin': 70,
#   'tmax': 85,
#   'prcp': 0.73,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2019-02-13',
#   'tmin': 39,
#   'tmax': 57,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.07},
#  {'date': '2020-05-30',
#   'tmin': 68,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2019-02-14',
#   'tmin': 29,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2020-06-05',
#   'tmin': 71,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2019-02-15',
#   'tmin': 49,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.51},
#  {'date': '2020-06-10',
#   'tmin': 76,
#   'tmax': 92,
#   'prcp': 0.05,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.18},
#  {'date': '2019-02-20',
#   'tmin': 32,
#   'tmax': 37,
#   'prcp': 0.39,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2020-06-19',
#   'tmin': 66,
#   'tmax': 86,
#   'prcp': 0.8,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2019-03-06',
#   'tmin': 27,
#   'tmax': 42,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2020-06-21',
#   'tmin': 62,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.24},
#  {'date': '2019-03-15',
#   'tmin': 58,
#   'tmax': 74,
#   'prcp': 0.31,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 13.42},
#  {'date': '2020-06-22',
#   'tmin': 70,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.83},
#  {'date': '2019-03-23',
#   'tmin': 35,
#   'tmax': 62,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2020-06-27',
#   'tmin': 66,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-03-29',
#   'tmin': 45,
#   'tmax': 74,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2020-06-29',
#   'tmin': 72,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2019-04-01',
#   'tmin': 34,
#   'tmax': 53,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2020-07-02',
#   'tmin': 70,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2019-04-04',
#   'tmin': 48,
#   'tmax': 75,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2020-07-17',
#   'tmin': 73,
#   'tmax': 95,
#   'prcp': 0.96,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.26},
#  {'date': '2019-04-05',
#   'tmin': 54,
#   'tmax': 60,
#   'prcp': 0.54,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2020-07-19',
#   'tmin': 72,
#   'tmax': 95,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2019-04-07',
#   'tmin': 52,
#   'tmax': 71,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2020-08-13',
#   'tmin': 73,
#   'tmax': 90,
#   'prcp': 0.06,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2019-04-18',
#   'tmin': 61,
#   'tmax': 80,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.41},
#  {'date': '2020-08-27',
#   'tmin': 71,
#   'tmax': 93,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
# ...
#   'tmin': 71,
#   'tmax': 92,
#   'prcp': 0.03,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.68},
#  {'date': '2018-09-08',
#   'tmin': 71,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2018-09-09',
#   'tmin': 67,
#   'tmax': 80,
#   'prcp': 0.15,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2018-09-11',
#   'tmin': 68,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2018-09-15',
#   'tmin': 73,
#   'tmax': 77,
#   'prcp': 1.85,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 15.88},
#  {'date': '2018-09-19',
#   'tmin': 65,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.79},
#  {'date': '2018-09-22',
#   'tmin': 67,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2018-09-25',
#   'tmin': 69,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2018-09-30',
#   'tmin': 62,
#   'tmax': 81,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2018-10-09',
#   'tmin': 67,
#   'tmax': 80,
#   'prcp': 0.07,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2018-10-14',
#   'tmin': 49,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2018-10-22',
#   'tmin': 34,
#   'tmax': 62,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2018-10-23',
#   'tmin': 42,
#   'tmax': 66,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2018-11-08',
#   'tmin': 51,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2018-11-09',
#   'tmin': 50,
#   'tmax': 53,
#   'prcp': 0.07,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2018-11-16',
#   'tmin': 34,
#   'tmax': 54,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2018-11-20',
#   'tmin': 38,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2018-11-22',
#   'tmin': 33,
#   'tmax': 50,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2018-11-28',
#   'tmin': 25,
#   'tmax': 42,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2018-12-03',
#   'tmin': 47,
#   'tmax': 68,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2018-12-08',
#   'tmin': 31,
#   'tmax': 43,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2018-12-11',
#   'tmin': 27,
#   'tmax': 44,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 2.0,
#   'awnd': 3.8},
#  {'date': '2018-12-12',
#   'tmin': 24,
#   'tmax': 45,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 1.2,
#   'awnd': 1.34},
#  {'date': '2018-12-13',
#   'tmin': 29,
#   'tmax': 51,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.24},
#  {'date': '2018-12-23',
#   'tmin': 28,
#   'tmax': 57,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2018-12-29',
#   'tmin': 45,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2019-01-05',
#   'tmin': 44,
#   'tmax': 61,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.62},
#  {'date': '2019-01-12',
#   'tmin': 30,
#   'tmax': 39,
#   'prcp': 0.07,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2019-01-14',
#   'tmin': 31,
#   'tmax': 41,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2019-01-21',
#   'tmin': 17,
#   'tmax': 31,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-01-22',
#   'tmin': 17,
#   'tmax': 39,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2019-02-02',
#   'tmin': 29,
#   'tmax': 60,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2019-02-09',
#   'tmin': 33,
#   'tmax': 46,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2019-02-17',
#   'tmin': 34,
#   'tmax': 40,
#   'prcp': 0.24,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2019-02-25',
#   'tmin': 37,
#   'tmax': 59,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.83},
#  {'date': '2019-02-26',
#   'tmin': 30,
#   'tmax': 63,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2019-03-01',
#   'tmin': 39,
#   'tmax': 47,
#   'prcp': 0.65,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2019-03-03',
#   'tmin': 42,
#   'tmax': 50,
#   'prcp': 0.81,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2019-03-09',
#   'tmin': 41,
#   'tmax': 48,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-03-11',
#   'tmin': 44,
#   'tmax': 66,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2019-03-18',
#   'tmin': 32,
#   'tmax': 60,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2019-03-24',
#   'tmin': 32,
#   'tmax': 71,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2019-04-06',
#   'tmin': 53,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2019-04-16',
#   'tmin': 38,
#   'tmax': 69,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-04-21',
#   'tmin': 44,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2019-05-06',
#   'tmin': 60,
#   'tmax': 77,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-05-13',
#   'tmin': 57,
#   'tmax': 74,
#   'prcp': 1.32,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2019-05-15',
#   'tmin': 43,
#   'tmax': 72,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2019-05-26',
#   'tmin': 72,
#   'tmax': 94,
#   'prcp': 0.05,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-05-30',
#   'tmin': 65,
#   'tmax': 96,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2019-06-02',
#   'tmin': 62,
#   'tmax': 88,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2019-06-08',
#   'tmin': 71,
#   'tmax': 79,
#   'prcp': 0.32,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.4},
#  {'date': '2019-06-16',
#   'tmin': 66,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.41},
#  {'date': '2019-06-17',
#   'tmin': 72,
#   'tmax': 93,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.84},
#  {'date': '2019-06-19',
#   'tmin': 71,
#   'tmax': 88,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2019-06-21',
#   'tmin': 65,
#   'tmax': 85,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2019-07-02',
#   'tmin': 68,
#   'tmax': 95,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2019-07-05',
#   'tmin': 70,
#   'tmax': 91,
#   'prcp': 0.31,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2019-07-08',
#   'tmin': 74,
#   'tmax': 92,
#   'prcp': 0.17,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2019-07-10',
#   'tmin': 72,
#   'tmax': 91,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2019-07-22',
#   'tmin': 74,
#   'tmax': 97,
#   'prcp': 0.06,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 12.08},
#  {'date': '2019-07-23',
#   'tmin': 64,
#   'tmax': 82,
#   'prcp': 1.16,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2019-07-29',
#   'tmin': 66,
#   'tmax': 93,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2019-08-03',
#   'tmin': 70,
#   'tmax': 86,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2019-08-07',
#   'tmin': 72,
#   'tmax': 91,
#   'prcp': 0.14,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2019-08-14',
#   'tmin': 73,
#   'tmax': 93,
#   'prcp': 0.12,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2019-08-20',
#   'tmin': 71,
#   'tmax': 93,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2019-08-24',
#   'tmin': 64,
#   'tmax': 72,
#   'prcp': 0.32,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2019-08-25',
#   'tmin': 63,
#   'tmax': 76,
#   'prcp': 0.04,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.49},
#  {'date': '2019-09-02',
#   'tmin': 70,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2019-09-06',
#   'tmin': 69,
#   'tmax': 87,
#   'prcp': 0.1,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2019-09-09',
#   'tmin': 71,
#   'tmax': 86,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2019-09-16',
#   'tmin': 69,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2019-09-20',
#   'tmin': 50,
#   'tmax': 79,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2019-09-26',
#   'tmin': 70,
#   'tmax': 94,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2019-10-16',
#   'tmin': 52,
#   'tmax': 66,
#   'prcp': 0.47,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2019-10-19',
#   'tmin': 39,
#   'tmax': 67,
#   'prcp': 0.03,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.13},
#  {'date': '2019-10-20',
#   'tmin': 56,
#   'tmax': 65,
#   'prcp': 1.57,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2019-10-29',
#   'tmin': 55,
#   'tmax': 71,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2019-11-07',
#   'tmin': 41,
#   'tmax': 70,
#   'prcp': 0.08,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2019-11-15',
#   'tmin': 39,
#   'tmax': 47,
#   'prcp': 0.07,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2019-11-18',
#   'tmin': 41,
#   'tmax': 47,
#   'prcp': 0.24,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2019-11-20',
#   'tmin': 38,
#   'tmax': 61,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2019-11-22',
#   'tmin': 49,
#   'tmax': 66,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2019-11-25',
#   'tmin': 32,
#   'tmax': 62,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.24},
#  {'date': '2019-11-26',
#   'tmin': 34,
#   'tmax': 65,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2019-12-07',
#   'tmin': 34,
#   'tmax': 52,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2019-12-15',
#   'tmin': 35,
#   'tmax': 61,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.7},
#  {'date': '2019-12-20',
#   'tmin': 25,
#   'tmax': 56,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.36},
#  {'date': '2019-12-25',
#   'tmin': 32,
#   'tmax': 58,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.46},
#  {'date': '2019-12-29',
#   'tmin': 57,
#   'tmax': 73,
#   'prcp': 0.09,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.72},
#  {'date': '2019-12-30',
#   'tmin': 49,
#   'tmax': 76,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 14.76},
#  {'date': '2020-01-02',
#   'tmin': 35,
#   'tmax': 58,
#   'prcp': 0.1,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.16},
#  {'date': '2020-01-07',
#   'tmin': 30,
#   'tmax': 52,
#   'prcp': 0.07,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2020-01-08',
#   'tmin': 29,
#   'tmax': 59,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2020-01-15',
#   'tmin': 57,
#   'tmax': 70,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2020-01-17',
#   'tmin': 36,
#   'tmax': 47,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2020-01-21',
#   'tmin': 24,
#   'tmax': 38,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2020-01-22',
#   'tmin': 24,
#   'tmax': 46,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.26},
#  {'date': '2020-02-01',
#   'tmin': 36,
#   'tmax': 45,
#   'prcp': 0.04,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.25},
#  {'date': '2020-02-05',
#   'tmin': 60,
#   'tmax': 64,
#   'prcp': 0.2,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.95},
#  {'date': '2020-02-06',
#   'tmin': 60,
#   'tmax': 70,
#   'prcp': 2.35,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.4},
#  {'date': '2020-02-10',
#   'tmin': 36,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2020-02-12',
#   'tmin': 51,
#   'tmax': 64,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2020-02-25',
#   'tmin': 48,
#   'tmax': 65,
#   'prcp': 0.16,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2020-03-12',
#   'tmin': 51,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2020-03-18',
#   'tmin': 46,
#   'tmax': 68,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2020-03-19',
#   'tmin': 59,
#   'tmax': 81,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.07},
#  {'date': '2020-03-23',
#   'tmin': 44,
#   'tmax': 50,
#   'prcp': 0.32,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.82},
#  {'date': '2020-03-24',
#   'tmin': 50,
#   'tmax': 55,
#   'prcp': 0.27,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2020-03-31',
#   'tmin': 46,
#   'tmax': 62,
#   'prcp': 0.23,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 9.62},
#  {'date': '2020-04-05',
#   'tmin': 47,
#   'tmax': 73,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2020-04-08',
#   'tmin': 58,
#   'tmax': 83,
#   'prcp': 0.43,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.71},
#  {'date': '2020-04-13',
#   'tmin': 61,
#   'tmax': 81,
#   'prcp': 0.39,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 15.43},
#  {'date': '2020-04-15',
#   'tmin': 40,
#   'tmax': 57,
#   'prcp': 0.14,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.61},
#  {'date': '2020-04-22',
#   'tmin': 41,
#   'tmax': 71,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.92},
#  {'date': '2020-04-25',
#   'tmin': 55,
#   'tmax': 61,
#   'prcp': 0.01,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2020-05-07',
#   'tmin': 40,
#   'tmax': 67,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2020-05-08',
#   'tmin': 44,
#   'tmax': 70,
#   'prcp': 0.05,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 11.41},
#  {'date': '2020-05-10',
#   'tmin': 36,
#   'tmax': 70,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2020-05-13',
#   'tmin': 42,
#   'tmax': 70,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 1.57},
#  {'date': '2020-05-14',
#   'tmin': 58,
#   'tmax': 81,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.05},
#  {'date': '2020-05-15',
#   'tmin': 60,
#   'tmax': 83,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 10.51},
#  {'date': '2020-05-16',
#   'tmin': 60,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.93},
#  {'date': '2020-05-18',
#   'tmin': 64,
#   'tmax': 70,
#   'prcp': 0.07,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 8.28},
#  {'date': '2020-05-22',
#   'tmin': 62,
#   'tmax': 82,
#   'prcp': 0.05,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.26},
#  {'date': '2020-05-25',
#   'tmin': 62,
#   'tmax': 76,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  {'date': '2020-06-01',
#   'tmin': 54,
#   'tmax': 77,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.47},
#  {'date': '2020-06-09',
#   'tmin': 73,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2020-06-17',
#   'tmin': 61,
#   'tmax': 76,
#   'prcp': 0.1,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 4.03},
#  {'date': '2020-06-18',
#   'tmin': 59,
#   'tmax': 80,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2020-06-28',
#   'tmin': 70,
#   'tmax': 91,
#   'prcp': 0.06,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 6.04},
#  {'date': '2020-06-30',
#   'tmin': 70,
#   'tmax': 92,
#   'prcp': 0.21,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.8},
#  {'date': '2020-07-01',
#   'tmin': 69,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 3.58},
#  {'date': '2020-07-06',
#   'tmin': 68,
#   'tmax': 92,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.37},
#  {'date': '2020-07-08',
#   'tmin': 74,
#   'tmax': 89,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2020-07-09',
#   'tmin': 73,
#   'tmax': 90,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 7.38},
#  {'date': '2020-07-11',
#   'tmin': 70,
#   'tmax': 92,
#   'prcp': 0.02,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.14},
#  {'date': '2020-07-14',
#   'tmin': 68,
#   'tmax': 95,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 2.91},
#  {'date': '2020-07-16',
#   'tmin': 74,
#   'tmax': 94,
#   'prcp': 0.0,
#   'snow': 0.0,
#   'snwd': 0.0,
#   'awnd': 5.59},
#  ...]

# %%
weather_by_date
# Out:
# {2017: {1: [{'date': '2017-01-04',
#     'tmin': 41,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-01-12',
#     'tmin': 54,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 12.53},
#    {'date': '2017-01-17',
#     'tmin': 47,
#     'tmax': 62,
#     'prcp': 0.04,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.28},
#    {'date': '2017-01-27',
#     'tmin': 30,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.49},
#    {'date': '2017-01-29',
#     'tmin': 30,
#     'tmax': 54,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-01-31',
#     'tmin': 31,
#     'tmax': 68,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 12.75},
#    {'date': '2017-01-03',
#     'tmin': 47,
#     'tmax': 56,
#     'prcp': 0.31,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2017-01-07',
#     'tmin': 20,
#     'tmax': 32,
#     'prcp': 0.6,
#     'snow': 0.5,
#     'snwd': 0.0,
#     'awnd': 9.62},
#    {'date': '2017-01-10',
#     'tmin': 24,
#     'tmax': 48,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 1.2,
#     'awnd': 5.14},
#    {'date': '2017-01-13',
#     'tmin': 50,
#     'tmax': 76,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38},
#    {'date': '2017-01-15',
#     'tmin': 40,
#     'tmax': 57,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-01-18',
#     'tmin': 45,
#     'tmax': 70,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.49},
#    {'date': '2017-01-21',
#     'tmin': 51,
#     'tmax': 55,
#     'prcp': 0.38,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-01-25',
#     'tmin': 36,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-01-28',
#     'tmin': 27,
#     'tmax': 52,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.4},
#    {'date': '2017-01-02',
#     'tmin': 47,
#     'tmax': 51,
#     'prcp': 1.08,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2017-01-05',
#     'tmin': 29,
#     'tmax': 44,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01},
#    {'date': '2017-01-06',
#     'tmin': 32,
#     'tmax': 43,
#     'prcp': 0.25,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-01-14',
#     'tmin': 42,
#     'tmax': 55,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-01-22',
#     'tmin': 53,
#     'tmax': 56,
#     'prcp': 0.09,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-01-01',
#     'tmin': 41,
#     'tmax': 50,
#     'prcp': 0.54,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.49},
#    {'date': '2017-01-08',
#     'tmin': 15,
#     'tmax': 27,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 1.2,
#     'awnd': 4.92},
#    {'date': '2017-01-16',
#     'tmin': 44,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-01-23',
#     'tmin': 43,
#     'tmax': 60,
#     'prcp': 0.28,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.84},
#    {'date': '2017-01-09',
#     'tmin': 9,
#     'tmax': 31,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 1.2,
#     'awnd': 2.46},
#    {'date': '2017-01-11',
#     'tmin': 40,
#     'tmax': 57,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-01-19',
#     'tmin': 36,
#     'tmax': 63,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.34},
#    {'date': '2017-01-20',
#     'tmin': 46,
#     'tmax': 59,
#     'prcp': 0.09,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-01-24',
#     'tmin': 41,
#     'tmax': 63,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-01-26',
#     'tmin': 43,
#     'tmax': 70,
#     'prcp': 0.06,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 13.42},
#    {'date': '2017-01-30',
#     'tmin': 30,
#     'tmax': 46,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26}],
#   2: [{'date': '2017-02-01',
#     'tmin': 42,
#     'tmax': 70,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-02-13',
#     'tmin': 37,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.16},
#    {'date': '2017-02-15',
#     'tmin': 39,
#     'tmax': 56,
#     'prcp': 0.34,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2017-02-17',
#     'tmin': 34,
#     'tmax': 66,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-02-09',
#     'tmin': 32,
#     'tmax': 60,
#     'prcp': 0.11,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.96},
#    {'date': '2017-02-18',
#     'tmin': 37,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-02-19',
#     'tmin': 44,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-02-20',
#     'tmin': 42,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.79},
#    {'date': '2017-02-23',
#     'tmin': 50,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2017-02-28',
#     'tmin': 50,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.16},
#    {'date': '2017-02-02',
#     'tmin': 37,
#     'tmax': 61,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.24},
#    {'date': '2017-02-03',
#     'tmin': 34,
#     'tmax': 49,
#     'prcp': 0.06,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-02-04',
#     'tmin': 26,
#     'tmax': 45,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-02-05',
#     'tmin': 27,
#     'tmax': 60,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-02-11',
#     'tmin': 41,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 12.3},
#    {'date': '2017-02-14',
#     'tmin': 30,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-02-22',
#     'tmin': 51,
#     'tmax': 70,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-02-27',
#     'tmin': 35,
#     'tmax': 66,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2017-02-07',
#     'tmin': 49,
#     'tmax': 76,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 12.53},
#    {'date': '2017-02-08',
#     'tmin': 54,
#     'tmax': 74,
#     'prcp': 0.09,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-02-21',
#     'tmin': 44,
#     'tmax': 66,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-02-24',
#     'tmin': 47,
#     'tmax': 80,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-02-25',
#     'tmin': 52,
#     'tmax': 81,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 13.2},
#    {'date': '2017-02-26',
#     'tmin': 37,
#     'tmax': 56,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-02-06',
#     'tmin': 31,
#     'tmax': 68,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-02-10',
#     'tmin': 26,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-02-12',
#     'tmin': 58,
#     'tmax': 83,
#     'prcp': 0.05,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.41},
#    {'date': '2017-02-16',
#     'tmin': 32,
#     'tmax': 53,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71}],
#   3: [{'date': '2017-03-14',
#     'tmin': 30,
#     'tmax': 54,
#     'prcp': 0.25,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.51},
#    {'date': '2017-03-19',
#     'tmin': 36,
#     'tmax': 57,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.16},
#    {'date': '2017-03-21',
#     'tmin': 50,
#     'tmax': 82,
#     'prcp': 0.2,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-03-27',
#     'tmin': 59,
#     'tmax': 79,
#     'prcp': 0.06,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.17},
#    {'date': '2017-03-30',
#     'tmin': 55,
#     'tmax': 67,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.95},
#    {'date': '2017-03-31',
#     'tmin': 58,
#     'tmax': 79,
#     'prcp': 0.42,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.74},
#    {'date': '2017-03-04',
#     'tmin': 25,
#     'tmax': 54,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.46},
#    {'date': '2017-03-07',
#     'tmin': 49,
#     'tmax': 74,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 13.87},
#    {'date': '2017-03-09',
#     'tmin': 37,
#     'tmax': 75,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-03-10',
#     'tmin': 41,
#     'tmax': 69,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.74},
#    {'date': '2017-03-11',
#     'tmin': 31,
#     'tmax': 50,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-03-26',
#     'tmin': 52,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.93},
#    {'date': '2017-03-28',
#     'tmin': 60,
#     'tmax': 80,
#     'prcp': 0.06,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-03-01',
#     'tmin': 59,
#     'tmax': 79,
#     'prcp': 0.97,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 17.22},
#    {'date': '2017-03-05',
#     'tmin': 30,
#     'tmax': 53,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26},
#    {'date': '2017-03-12',
#     'tmin': 30,
#     'tmax': 48,
#     'prcp': 0.03,
#     'snow': 0.3,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-03-16',
#     'tmin': 24,
#     'tmax': 50,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-03-18',
#     'tmin': 44,
#     'tmax': 64,
#     'prcp': 0.5,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.83},
#    {'date': '2017-03-24',
#     'tmin': 37,
#     'tmax': 71,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.62},
#    {'date': '2017-03-25',
#     'tmin': 52,
#     'tmax': 76,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.74},
#    {'date': '2017-03-29',
#     'tmin': 55,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-03-02',
#     'tmin': 39,
#     'tmax': 62,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-03-03',
#     'tmin': 31,
#     'tmax': 54,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-03-08',
#     'tmin': 46,
#     'tmax': 69,
#     'prcp': 0.05,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.5},
#    {'date': '2017-03-20',
#     'tmin': 30,
#     'tmax': 66,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-03-06',
#     'tmin': 34,
#     'tmax': 65,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-03-13',
#     'tmin': 26,
#     'tmax': 42,
#     'prcp': 0.56,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.28},
#    {'date': '2017-03-15',
#     'tmin': 24,
#     'tmax': 40,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.51},
#    {'date': '2017-03-17',
#     'tmin': 23,
#     'tmax': 58,
#     'prcp': 0.03,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-03-22',
#     'tmin': 39,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.28},
#    {'date': '2017-03-23',
#     'tmin': 31,
#     'tmax': 56,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38}],
#   4: [{'date': '2017-04-12',
#     'tmin': 56,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2017-04-19',
#     'tmin': 55,
#     'tmax': 69,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-04-26',
#     'tmin': 56,
#     'tmax': 81,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2017-04-27',
#     'tmin': 62,
#     'tmax': 82,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.51},
#    {'date': '2017-04-29',
#     'tmin': 72,
#     'tmax': 89,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.07},
#    {'date': '2017-04-30',
#     'tmin': 70,
#     'tmax': 86,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.51},
#    {'date': '2017-04-08',
#     'tmin': 34,
#     'tmax': 67,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13},
#    {'date': '2017-04-22',
#     'tmin': 56,
#     'tmax': 87,
#     'prcp': 0.09,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.4},
#    {'date': '2017-04-23',
#     'tmin': 53,
#     'tmax': 56,
#     'prcp': 0.77,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.18},
#    {'date': '2017-04-28',
#     'tmin': 69,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.17},
#    {'date': '2017-04-04',
#     'tmin': 63,
#     'tmax': 82,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 12.97},
#    {'date': '2017-04-10',
#     'tmin': 49,
#     'tmax': 78,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.62},
#    {'date': '2017-04-13',
#     'tmin': 54,
#     'tmax': 80,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-04-14',
#     'tmin': 53,
#     'tmax': 81,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-04-24',
#     'tmin': 53,
#     'tmax': 60,
#     'prcp': 4.51,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.96},
#    {'date': '2017-04-03',
#     'tmin': 50,
#     'tmax': 76,
#     'prcp': 0.4,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.17},
#    {'date': '2017-04-05',
#     'tmin': 53,
#     'tmax': 78,
#     'prcp': 0.32,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-04-06',
#     'tmin': 50,
#     'tmax': 70,
#     'prcp': 0.09,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 15.21},
#    {'date': '2017-04-07',
#     'tmin': 43,
#     'tmax': 59,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.86},
#    {'date': '2017-04-09',
#     'tmin': 38,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-04-11',
#     'tmin': 55,
#     'tmax': 82,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.51},
#    {'date': '2017-04-18',
#     'tmin': 61,
#     'tmax': 74,
#     'prcp': 0.03,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.62},
#    {'date': '2017-04-25',
#     'tmin': 58,
#     'tmax': 70,
#     'prcp': 2.17,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.93},
#    {'date': '2017-04-01',
#     'tmin': 49,
#     'tmax': 75,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-04-02',
#     'tmin': 49,
#     'tmax': 69,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-04-15',
#     'tmin': 61,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.62},
#    {'date': '2017-04-16',
#     'tmin': 60,
#     'tmax': 82,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 12.75},
#    {'date': '2017-04-17',
#     'tmin': 62,
#     'tmax': 86,
#     'prcp': 0.05,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.84},
#    {'date': '2017-04-20',
#     'tmin': 56,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-04-21',
#     'tmin': 63,
#     'tmax': 89,
#     'prcp': 0.21,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.93}],
#   5: [{'date': '2017-05-05',
#     'tmin': 56,
#     'tmax': 78,
#     'prcp': 1.48,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 15.88},
#    {'date': '2017-05-14',
#     'tmin': 49,
#     'tmax': 81,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.16},
#    {'date': '2017-05-16',
#     'tmin': 57,
#     'tmax': 87,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-05-27',
#     'tmin': 61,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-05-31',
#     'tmin': 68,
#     'tmax': 86,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-05-03',
#     'tmin': 53,
#     'tmax': 79,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2017-05-04',
#     'tmin': 57,
#     'tmax': 80,
#     'prcp': 0.29,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.74},
#    {'date': '2017-05-06',
#     'tmin': 53,
#     'tmax': 67,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.96},
#    {'date': '2017-05-09',
#     'tmin': 43,
#     'tmax': 64,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.79},
#    {'date': '2017-05-17',
#     'tmin': 66,
#     'tmax': 89,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.95},
#    {'date': '2017-05-21',
#     'tmin': 60,
#     'tmax': 76,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-05-02',
#     'tmin': 60,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.41},
#    {'date': '2017-05-07',
#     'tmin': 45,
#     'tmax': 69,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-05-08',
#     'tmin': 43,
#     'tmax': 71,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-05-10',
#     'tmin': 57,
#     'tmax': 83,
#     'prcp': 0.45,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-05-15',
#     'tmin': 60,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-05-24',
#     'tmin': 65,
#     'tmax': 74,
#     'prcp': 0.29,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-05-25',
#     'tmin': 60,
#     'tmax': 76,
#     'prcp': 0.82,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.41},
#    {'date': '2017-05-28',
#     'tmin': 67,
#     'tmax': 86,
#     'prcp': 0.08,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-05-13',
#     'tmin': 52,
#     'tmax': 66,
#     'prcp': 0.23,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-05-19',
#     'tmin': 68,
#     'tmax': 89,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-05-20',
#     'tmin': 67,
#     'tmax': 90,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38},
#    {'date': '2017-05-22',
#     'tmin': 68,
#     'tmax': 80,
#     'prcp': 0.3,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-05-23',
#     'tmin': 67,
#     'tmax': 71,
#     'prcp': 0.69,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-05-29',
#     'tmin': 64,
#     'tmax': 87,
#     'prcp': 0.08,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13},
#    {'date': '2017-05-01',
#     'tmin': 68,
#     'tmax': 85,
#     'prcp': 0.29,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 15.66},
#    {'date': '2017-05-11',
#     'tmin': 61,
#     'tmax': 84,
#     'prcp': 0.48,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-05-12',
#     'tmin': 54,
#     'tmax': 61,
#     'prcp': 0.07,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-05-18',
#     'tmin': 66,
#     'tmax': 86,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.96},
#    {'date': '2017-05-26',
#     'tmin': 59,
#     'tmax': 81,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.83},
#    {'date': '2017-05-30',
#     'tmin': 68,
#     'tmax': 82,
#     'prcp': 0.06,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03}],
#   6: [{'date': '2017-06-07',
#     'tmin': 59,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.29},
#    {'date': '2017-06-19',
#     'tmin': 70,
#     'tmax': 92,
#     'prcp': 0.09,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.86},
#    {'date': '2017-06-24',
#     'tmin': 71,
#     'tmax': 91,
#     'prcp': 0.46,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.83},
#    {'date': '2017-06-26',
#     'tmin': 60,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2017-06-29',
#     'tmin': 60,
#     'tmax': 87,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-06-06',
#     'tmin': 64,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-06-08',
#     'tmin': 55,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38},
#    {'date': '2017-06-09',
#     'tmin': 53,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2017-06-13',
#     'tmin': 67,
#     'tmax': 89,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-06-17',
#     'tmin': 72,
#     'tmax': 86,
#     'prcp': 0.21,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-06-22',
#     'tmin': 71,
#     'tmax': 84,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-06-23',
#     'tmin': 73,
#     'tmax': 91,
#     'prcp': 0.04,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 13.65},
#    {'date': '2017-06-27',
#     'tmin': 59,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-06-10',
#     'tmin': 61,
#     'tmax': 89,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-06-20',
#     'tmin': 67,
#     'tmax': 82,
#     'prcp': 0.72,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-06-21',
#     'tmin': 66,
#     'tmax': 85,
#     'prcp': 0.2,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-06-30',
#     'tmin': 69,
#     'tmax': 87,
#     'prcp': 0.05,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.83},
#    {'date': '2017-06-01',
#     'tmin': 62,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.57},
#    {'date': '2017-06-02',
#     'tmin': 61,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-06-04',
#     'tmin': 61,
#     'tmax': 90,
#     'prcp': 0.38,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-06-12',
#     'tmin': 67,
#     'tmax': 89,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.49},
#    {'date': '2017-06-14',
#     'tmin': 66,
#     'tmax': 93,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-06-15',
#     'tmin': 70,
#     'tmax': 91,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2017-06-03',
#     'tmin': 57,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2017-06-05',
#     'tmin': 67,
#     'tmax': 85,
#     'prcp': 1.54,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-06-11',
#     'tmin': 67,
#     'tmax': 90,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26},
#    {'date': '2017-06-16',
#     'tmin': 70,
#     'tmax': 89,
#     'prcp': 2.3,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2017-06-18',
#     'tmin': 74,
#     'tmax': 91,
#     'prcp': 0.17,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.72},
#    {'date': '2017-06-25',
#     'tmin': 67,
#     'tmax': 84,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-06-28',
#     'tmin': 57,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.25}],
#   7: [{'date': '2017-07-01',
#     'tmin': 73,
#     'tmax': 90,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.17},
#    {'date': '2017-07-03',
#     'tmin': 70,
#     'tmax': 93,
#     'prcp': 0.15,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-07-07',
#     'tmin': 73,
#     'tmax': 91,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.95},
#    {'date': '2017-07-09',
#     'tmin': 69,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2017-07-21',
#     'tmin': 74,
#     'tmax': 98,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2017-07-24',
#     'tmin': 71,
#     'tmax': 93,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.16},
#    {'date': '2017-07-31',
#     'tmin': 58,
#     'tmax': 87,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-07-04',
#     'tmin': 71,
#     'tmax': 92,
#     'prcp': 0.84,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-07-15',
#     'tmin': 75,
#     'tmax': 94,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-07-23',
#     'tmin': 71,
#     'tmax': 102,
#     'prcp': 0.56,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.95},
#    {'date': '2017-07-27',
#     'tmin': 72,
#     'tmax': 94,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-07-06',
#     'tmin': 68,
#     'tmax': 93,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-07-08',
#     'tmin': 71,
#     'tmax': 95,
#     'prcp': 0.05,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.49},
#    {'date': '2017-07-10',
#     'tmin': 70,
#     'tmax': 90,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-07-12',
#     'tmin': 75,
#     'tmax': 94,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.72},
#    {'date': '2017-07-17',
#     'tmin': 71,
#     'tmax': 90,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-07-25',
#     'tmin': 74,
#     'tmax': 91,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-07-26',
#     'tmin': 72,
#     'tmax': 90,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-07-29',
#     'tmin': 70,
#     'tmax': 82,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.5},
#    {'date': '2017-07-02',
#     'tmin': 71,
#     'tmax': 92,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-07-05',
#     'tmin': 70,
#     'tmax': 89,
#     'prcp': 0.47,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.46},
#    {'date': '2017-07-11',
#     'tmin': 71,
#     'tmax': 95,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.93},
#    {'date': '2017-07-16',
#     'tmin': 73,
#     'tmax': 91,
#     'prcp': 0.05,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2017-07-19',
#     'tmin': 67,
#     'tmax': 94,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.68},
#    {'date': '2017-07-20',
#     'tmin': 71,
#     'tmax': 99,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-07-22',
#     'tmin': 76,
#     'tmax': 101,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.74},
#    {'date': '2017-07-13',
#     'tmin': 78,
#     'tmax': 97,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.5},
#    {'date': '2017-07-14',
#     'tmin': 77,
#     'tmax': 97,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.4},
#    {'date': '2017-07-18',
#     'tmin': 71,
#     'tmax': 89,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2017-07-28',
#     'tmin': 75,
#     'tmax': 94,
#     'prcp': 0.21,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-07-30',
#     'tmin': 63,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26}],
#   8: [{'date': '2017-08-02',
#     'tmin': 66,
#     'tmax': 91,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2017-08-05',
#     'tmin': 68,
#     'tmax': 92,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.49},
#    {'date': '2017-08-12',
#     'tmin': 73,
#     'tmax': 92,
#     'prcp': 0.48,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2017-08-29',
#     'tmin': 64,
#     'tmax': 71,
#     'prcp': 0.22,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.5},
#    {'date': '2017-08-08',
#     'tmin': 68,
#     'tmax': 78,
#     'prcp': 1.5,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-08-10',
#     'tmin': 63,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2017-08-16',
#     'tmin': 74,
#     'tmax': 92,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2017-08-17',
#     'tmin': 75,
#     'tmax': 94,
#     'prcp': 0.24,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-08-22',
#     'tmin': 74,
#     'tmax': 96,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-08-25',
#     'tmin': 68,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2017-08-01',
#     'tmin': 60,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-08-06',
#     'tmin': 65,
#     'tmax': 90,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-08-09',
#     'tmin': 67,
#     'tmax': 84,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-08-11',
#     'tmin': 73,
#     'tmax': 89,
#     'prcp': 1.2,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.25},
#    {'date': '2017-08-14',
#     'tmin': 73,
#     'tmax': 88,
#     'prcp': 0.21,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-08-15',
#     'tmin': 76,
#     'tmax': 91,
#     'prcp': 0.07,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-08-23',
#     'tmin': 74,
#     'tmax': 95,
#     'prcp': 0.21,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-08-24',
#     'tmin': 71,
#     'tmax': 84,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-08-26',
#     'tmin': 68,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-08-28',
#     'tmin': 62,
#     'tmax': 78,
#     'prcp': 0.03,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.41},
#    {'date': '2017-08-03',
#     'tmin': 68,
#     'tmax': 94,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-08-04',
#     'tmin': 68,
#     'tmax': 92,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.16},
#    {'date': '2017-08-07',
#     'tmin': 74,
#     'tmax': 92,
#     'prcp': 0.04,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.96},
#    {'date': '2017-08-13',
#     'tmin': 73,
#     'tmax': 81,
#     'prcp': 0.73,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26},
#    {'date': '2017-08-21',
#     'tmin': 71,
#     'tmax': 93,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13},
#    {'date': '2017-08-27',
#     'tmin': 63,
#     'tmax': 81,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.17},
#    {'date': '2017-08-31',
#     'tmin': 69,
#     'tmax': 87,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.16},
#    {'date': '2017-08-18',
#     'tmin': 75,
#     'tmax': 98,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38},
#    {'date': '2017-08-19',
#     'tmin': 73,
#     'tmax': 92,
#     'prcp': 0.05,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-08-20',
#     'tmin': 71,
#     'tmax': 95,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-08-30',
#     'tmin': 59,
#     'tmax': 84,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.79}],
#   9: [{'date': '2017-09-07',
#     'tmin': 53,
#     'tmax': 76,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-09-10',
#     'tmin': 51,
#     'tmax': 71,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.95},
#    {'date': '2017-09-12',
#     'tmin': 63,
#     'tmax': 79,
#     'prcp': 0.63,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.74},
#    {'date': '2017-09-19',
#     'tmin': 64,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.25},
#    {'date': '2017-09-26',
#     'tmin': 69,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-09-27',
#     'tmin': 68,
#     'tmax': 91,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2017-09-03',
#     'tmin': 62,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.25},
#    {'date': '2017-09-14',
#     'tmin': 64,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-09-15',
#     'tmin': 63,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.79},
#    {'date': '2017-09-16',
#     'tmin': 62,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-09-17',
#     'tmin': 63,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2017-09-21',
#     'tmin': 65,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.79},
#    {'date': '2017-09-23',
#     'tmin': 61,
#     'tmax': 87,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-09-24',
#     'tmin': 63,
#     'tmax': 87,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2017-09-29',
#     'tmin': 60,
#     'tmax': 72,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.04},
#    {'date': '2017-09-30',
#     'tmin': 54,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.83},
#    {'date': '2017-09-02',
#     'tmin': 61,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26},
#    {'date': '2017-09-08',
#     'tmin': 51,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.68},
#    {'date': '2017-09-09',
#     'tmin': 53,
#     'tmax': 76,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38},
#    {'date': '2017-09-18',
#     'tmin': 65,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-09-20',
#     'tmin': 62,
#     'tmax': 91,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-09-04',
#     'tmin': 59,
#     'tmax': 87,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-09-13',
#     'tmin': 61,
#     'tmax': 84,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-09-22',
#     'tmin': 61,
#     'tmax': 89,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.24},
#    {'date': '2017-09-25',
#     'tmin': 63,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-09-01',
#     'tmin': 64,
#     'tmax': 78,
#     'prcp': 1.06,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.83},
#    {'date': '2017-09-05',
#     'tmin': 64,
#     'tmax': 90,
#     'prcp': 0.06,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-09-06',
#     'tmin': 61,
#     'tmax': 82,
#     'prcp': 0.52,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-09-11',
#     'tmin': 58,
#     'tmax': 67,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 12.75},
#    {'date': '2017-09-28',
#     'tmin': 63,
#     'tmax': 94,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13}],
#   10: [{'date': '2017-10-01',
#     'tmin': 48,
#     'tmax': 71,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.16},
#    {'date': '2017-10-07',
#     'tmin': 59,
#     'tmax': 86,
#     'prcp': 0.15,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26},
#    {'date': '2017-10-16',
#     'tmin': 51,
#     'tmax': 69,
#     'prcp': 0.25,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-10-22',
#     'tmin': 51,
#     'tmax': 79,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13},
#    {'date': '2017-10-27',
#     'tmin': 38,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-10-04',
#     'tmin': 50,
#     'tmax': 82,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.24},
#    {'date': '2017-10-05',
#     'tmin': 54,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13},
#    {'date': '2017-10-08',
#     'tmin': 74,
#     'tmax': 84,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.28},
#    {'date': '2017-10-09',
#     'tmin': 74,
#     'tmax': 92,
#     'prcp': 0.09,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.86},
#    {'date': '2017-10-10',
#     'tmin': 75,
#     'tmax': 90,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-10-17',
#     'tmin': 42,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2017-10-18',
#     'tmin': 37,
#     'tmax': 68,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.68},
#    {'date': '2017-10-19',
#     'tmin': 42,
#     'tmax': 76,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.12},
#    {'date': '2017-10-03',
#     'tmin': 50,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26},
#    {'date': '2017-10-15',
#     'tmin': 62,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.84},
#    {'date': '2017-10-24',
#     'tmin': 52,
#     'tmax': 72,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.49},
#    {'date': '2017-10-25',
#     'tmin': 42,
#     'tmax': 66,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-10-28',
#     'tmin': 47,
#     'tmax': 74,
#     'prcp': 0.76,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-10-20',
#     'tmin': 43,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01},
#    {'date': '2017-10-21',
#     'tmin': 48,
#     'tmax': 79,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01},
#    {'date': '2017-10-23',
#     'tmin': 61,
#     'tmax': 76,
#     'prcp': 1.12,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.74},
#    {'date': '2017-10-30',
#     'tmin': 36,
#     'tmax': 59,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.93},
#    {'date': '2017-10-31',
#     'tmin': 39,
#     'tmax': 69,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.79},
#    {'date': '2017-10-02',
#     'tmin': 47,
#     'tmax': 76,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-10-06',
#     'tmin': 55,
#     'tmax': 86,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-10-11',
#     'tmin': 73,
#     'tmax': 89,
#     'prcp': 1.12,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2017-10-12',
#     'tmin': 65,
#     'tmax': 77,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.28},
#    {'date': '2017-10-13',
#     'tmin': 63,
#     'tmax': 71,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38},
#    {'date': '2017-10-14',
#     'tmin': 62,
#     'tmax': 78,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13},
#    {'date': '2017-10-26',
#     'tmin': 40,
#     'tmax': 63,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2017-10-29',
#     'tmin': 41,
#     'tmax': 68,
#     'prcp': 0.78,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61}],
#   11: [{'date': '2017-11-01',
#     'tmin': 46,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.25},
#    {'date': '2017-11-07',
#     'tmin': 44,
#     'tmax': 63,
#     'prcp': 0.1,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.49},
#    {'date': '2017-11-12',
#     'tmin': 28,
#     'tmax': 49,
#     'prcp': 0.03,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.57},
#    {'date': '2017-11-15',
#     'tmin': 33,
#     'tmax': 54,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-11-17',
#     'tmin': 34,
#     'tmax': 57,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-11-21',
#     'tmin': 30,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-11-27',
#     'tmin': 26,
#     'tmax': 61,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.34},
#    {'date': '2017-11-03',
#     'tmin': 52,
#     'tmax': 81,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01},
#    {'date': '2017-11-11',
#     'tmin': 28,
#     'tmax': 46,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2017-11-16',
#     'tmin': 36,
#     'tmax': 67,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13},
#    {'date': '2017-11-25',
#     'tmin': 29,
#     'tmax': 67,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-11-28',
#     'tmin': 29,
#     'tmax': 65,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.24},
#    {'date': '2017-11-02',
#     'tmin': 55,
#     'tmax': 78,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01},
#    {'date': '2017-11-04',
#     'tmin': 56,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.28},
#    {'date': '2017-11-06',
#     'tmin': 53,
#     'tmax': 76,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-11-10',
#     'tmin': 35,
#     'tmax': 58,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2017-11-13',
#     'tmin': 42,
#     'tmax': 60,
#     'prcp': 0.64,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.25},
#    {'date': '2017-11-14',
#     'tmin': 43,
#     'tmax': 52,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.72},
#    {'date': '2017-11-22',
#     'tmin': 42,
#     'tmax': 62,
#     'prcp': 0.03,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-11-29',
#     'tmin': 40,
#     'tmax': 70,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.46},
#    {'date': '2017-11-30',
#     'tmin': 35,
#     'tmax': 69,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.12},
#    {'date': '2017-11-08',
#     'tmin': 43,
#     'tmax': 45,
#     'prcp': 0.13,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.28},
#    {'date': '2017-11-09',
#     'tmin': 45,
#     'tmax': 50,
#     'prcp': 0.27,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2017-11-23',
#     'tmin': 29,
#     'tmax': 50,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.68},
#    {'date': '2017-11-24',
#     'tmin': 26,
#     'tmax': 57,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.57},
#    {'date': '2017-11-26',
#     'tmin': 33,
#     'tmax': 62,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-11-05',
#     'tmin': 51,
#     'tmax': 70,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.46},
#    {'date': '2017-11-18',
#     'tmin': 33,
#     'tmax': 67,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.41},
#    {'date': '2017-11-19',
#     'tmin': 34,
#     'tmax': 64,
#     'prcp': 0.08,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.17},
#    {'date': '2017-11-20',
#     'tmin': 28,
#     'tmax': 57,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01}],
#   12: [{'date': '2017-12-09',
#     'tmin': 32,
#     'tmax': 34,
#     'prcp': 0.3,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-12-11',
#     'tmin': 26,
#     'tmax': 55,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-12-13',
#     'tmin': 21,
#     'tmax': 43,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.72},
#    {'date': '2017-12-16',
#     'tmin': 24,
#     'tmax': 50,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-12-19',
#     'tmin': 36,
#     'tmax': 70,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-12-21',
#     'tmin': 36,
#     'tmax': 53,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2017-12-24',
#     'tmin': 43,
#     'tmax': 61,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38},
#    {'date': '2017-12-27',
#     'tmin': 27,
#     'tmax': 45,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-12-31',
#     'tmin': 23,
#     'tmax': 35,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.07},
#    {'date': '2017-12-02',
#     'tmin': 45,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2017-12-05',
#     'tmin': 41,
#     'tmax': 69,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-12-06',
#     'tmin': 41,
#     'tmax': 57,
#     'prcp': 0.24,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2017-12-08',
#     'tmin': 32,
#     'tmax': 43,
#     'prcp': 1.33,
#     'snow': 0.3,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-12-10',
#     'tmin': 27,
#     'tmax': 43,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2017-12-17',
#     'tmin': 27,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.24},
#    {'date': '2017-12-07',
#     'tmin': 40,
#     'tmax': 49,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.46},
#    {'date': '2017-12-15',
#     'tmin': 31,
#     'tmax': 43,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2017-12-22',
#     'tmin': 36,
#     'tmax': 61,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2017-12-23',
#     'tmin': 48,
#     'tmax': 71,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 12.08},
#    {'date': '2017-12-01',
#     'tmin': 41,
#     'tmax': 63,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2017-12-03',
#     'tmin': 42,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.46},
#    {'date': '2017-12-12',
#     'tmin': 30,
#     'tmax': 53,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.62},
#    {'date': '2017-12-18',
#     'tmin': 35,
#     'tmax': 61,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01},
#    {'date': '2017-12-20',
#     'tmin': 48,
#     'tmax': 56,
#     'prcp': 0.42,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.46},
#    {'date': '2017-12-25',
#     'tmin': 30,
#     'tmax': 47,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2017-12-26',
#     'tmin': 27,
#     'tmax': 43,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.24},
#    {'date': '2017-12-28',
#     'tmin': 18,
#     'tmax': 30,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.83},
#    {'date': '2017-12-29',
#     'tmin': 15,
#     'tmax': 42,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01},
#    {'date': '2017-12-30',
#     'tmin': 27,
#     'tmax': 52,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2017-12-04',
#     'tmin': 33,
#     'tmax': 61,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.46},
#    {'date': '2017-12-14',
#     'tmin': 30,
#     'tmax': 57,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38}]},
#  2018: {1: [{'date': '2018-01-05',
#     'tmin': 12,
#     'tmax': 31,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2018-01-13',
#     'tmin': 29,
#     'tmax': 56,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.62},
#    {'date': '2018-01-15',
#     'tmin': 17,
#     'tmax': 39,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2018-01-16',
#     'tmin': 20,
#     'tmax': 47,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.79},
#    {'date': '2018-01-18',
#     'tmin': 10,
#     'tmax': 34,
#     'prcp': 0.0,
#     'snow': 0.2,
#     'snwd': 5.9,
#     'awnd': 5.59},
#    {'date': '2018-01-22',
#     'tmin': 38,
#     'tmax': 62,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2018-01-03',
#     'tmin': 9,
#     'tmax': 32,
#     'prcp': 0.06,
#     'snow': 0.9,
#     'snwd': 0.0,
#     'awnd': 4.25},
#    {'date': '2018-01-08',
#     'tmin': 16,
#     'tmax': 47,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2018-01-11',
#     'tmin': 41,
#     'tmax': 64,
# ...
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2018-08-27',
#     'tmin': 69,
#     'tmax': 93,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2018-08-31',
#     'tmin': 69,
#     'tmax': 92,
#     'prcp': 0.27,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8}],
#   9: [{'date': '2018-09-01',
#     'tmin': 71,
#     'tmax': 93,
#     'prcp': 0.19,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2018-09-12',
#     'tmin': 72,
#     'tmax': 88,
#     'prcp': 0.13,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2018-09-17',
#     'tmin': 72,
#     'tmax': 88,
#     'prcp': 1.32,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.63},
#    {'date': '2018-09-21',
#     'tmin': 70,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2018-09-23',
#     'tmin': 64,
#     'tmax': 76,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2018-09-24',
#     'tmin': 64,
#     'tmax': 74,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2018-09-29',
#     'tmin': 60,
#     'tmax': 82,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2018-09-02',
#     'tmin': 69,
#     'tmax': 90,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.24},
#    {'date': '2018-09-04',
#     'tmin': 72,
#     'tmax': 92,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2018-09-16',
#     'tmin': 73,
#     'tmax': 76,
#     'prcp': 0.9,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 14.99},
#    {'date': '2018-09-18',
#     'tmin': 71,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.93},
#    {'date': '2018-09-03',
#     'tmin': 69,
#     'tmax': 91,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.12},
#    {'date': '2018-09-05',
#     'tmin': 71,
#     'tmax': 91,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2018-09-06',
#     'tmin': 71,
#     'tmax': 92,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2018-09-07',
#     'tmin': 71,
#     'tmax': 92,
#     'prcp': 0.03,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.68},
#    {'date': '2018-09-08',
#     'tmin': 71,
#     'tmax': 91,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13},
#    {'date': '2018-09-09',
#     'tmin': 67,
#     'tmax': 80,
#     'prcp': 0.15,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2018-09-11',
#     'tmin': 68,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2018-09-15',
#     'tmin': 73,
#     'tmax': 77,
#     'prcp': 1.85,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 15.88},
#    {'date': '2018-09-19',
#     'tmin': 65,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.79},
#    {'date': '2018-09-22',
#     'tmin': 67,
#     'tmax': 88,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2018-09-25',
#     'tmin': 69,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2018-09-30',
#     'tmin': 62,
#     'tmax': 81,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2018-09-13',
#     'tmin': 74,
#     'tmax': 81,
#     'prcp': 0.28,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.18},
#    {'date': '2018-09-14',
#     'tmin': 73,
#     'tmax': 79,
#     'prcp': 2.5,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 20.36},
#    {'date': '2018-09-20',
#     'tmin': 67,
#     'tmax': 87,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.25},
#    {'date': '2018-09-26',
#     'tmin': 66,
#     'tmax': 87,
#     'prcp': 0.12,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2018-09-27',
#     'tmin': 70,
#     'tmax': 79,
#     'prcp': 0.21,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.25},
#    {'date': '2018-09-10',
#     'tmin': 67,
#     'tmax': 88,
#     'prcp': 0.26,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2018-09-28',
#     'tmin': 65,
#     'tmax': 79,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92}],
#   10: [{'date': '2018-10-02',
#     'tmin': 61,
#     'tmax': 83,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2018-10-05',
#     'tmin': 68,
#     'tmax': 90,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2018-10-06',
#     'tmin': 68,
#     'tmax': 82,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2018-10-19',
#     'tmin': 39,
#     'tmax': 69,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13},
#    {'date': '2018-10-28',
#     'tmin': 42,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.5},
#    {'date': '2018-10-31',
#     'tmin': 42,
#     'tmax': 72,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.5},
#    {'date': '2018-10-16',
#     'tmin': 64,
#     'tmax': 75,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.92},
#    {'date': '2018-10-20',
#     'tmin': 54,
#     'tmax': 67,
#     'prcp': 0.21,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2018-10-21',
#     'tmin': 37,
#     'tmax': 58,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2018-10-26',
#     'tmin': 42,
#     'tmax': 52,
#     'prcp': 1.58,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2018-10-29',
#     'tmin': 39,
#     'tmax': 65,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2018-10-30',
#     'tmin': 35,
#     'tmax': 65,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.12},
#    {'date': '2018-10-09',
#     'tmin': 67,
#     'tmax': 80,
#     'prcp': 0.07,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.49},
#    {'date': '2018-10-14',
#     'tmin': 49,
#     'tmax': 65,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2018-10-22',
#     'tmin': 34,
#     'tmax': 62,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2018-10-23',
#     'tmin': 42,
#     'tmax': 66,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2018-10-10',
#     'tmin': 69,
#     'tmax': 81,
#     'prcp': 0.1,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2018-10-12',
#     'tmin': 51,
#     'tmax': 71,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2018-10-24',
#     'tmin': 38,
#     'tmax': 61,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2018-10-27',
#     'tmin': 47,
#     'tmax': 55,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.5},
#    {'date': '2018-10-01',
#     'tmin': 60,
#     'tmax': 82,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01},
#    {'date': '2018-10-03',
#     'tmin': 64,
#     'tmax': 86,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.68},
#    {'date': '2018-10-04',
#     'tmin': 66,
#     'tmax': 89,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.68},
#    {'date': '2018-10-07',
#     'tmin': 66,
#     'tmax': 87,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2018-10-08',
#     'tmin': 69,
#     'tmax': 85,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26},
#    {'date': '2018-10-11',
#     'tmin': 63,
#     'tmax': 79,
#     'prcp': 2.6,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.63},
#    {'date': '2018-10-13',
#     'tmin': 48,
#     'tmax': 70,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2018-10-15',
#     'tmin': 59,
#     'tmax': 80,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2018-10-17',
#     'tmin': 53,
#     'tmax': 71,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2018-10-18',
#     'tmin': 43,
#     'tmax': 62,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.47},
#    {'date': '2018-10-25',
#     'tmin': 36,
#     'tmax': 55,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.34}],
#   11: [{'date': '2018-11-03',
#     'tmin': 39,
#     'tmax': 61,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2018-11-07',
#     'tmin': 49,
#     'tmax': 73,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.34},
#    {'date': '2018-11-11',
#     'tmin': 28,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2018-11-17',
#     'tmin': 33,
#     'tmax': 59,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.57},
#    {'date': '2018-11-30',
#     'tmin': 42,
#     'tmax': 68,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.72},
#    {'date': '2018-11-12',
#     'tmin': 35,
#     'tmax': 48,
#     'prcp': 3.17,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2018-11-13',
#     'tmin': 44,
#     'tmax': 51,
#     'prcp': 1.19,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91},
#    {'date': '2018-11-15',
#     'tmin': 36,
#     'tmax': 43,
#     'prcp': 0.88,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.29},
#    {'date': '2018-11-18',
#     'tmin': 37,
#     'tmax': 59,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.57},
#    {'date': '2018-11-19',
#     'tmin': 43,
#     'tmax': 65,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2018-11-23',
#     'tmin': 27,
#     'tmax': 45,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.83},
#    {'date': '2018-11-26',
#     'tmin': 39,
#     'tmax': 63,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.84},
#    {'date': '2018-11-08',
#     'tmin': 51,
#     'tmax': 65,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.16},
#    {'date': '2018-11-09',
#     'tmin': 50,
#     'tmax': 53,
#     'prcp': 0.07,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.37},
#    {'date': '2018-11-16',
#     'tmin': 34,
#     'tmax': 54,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2018-11-20',
#     'tmin': 38,
#     'tmax': 64,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2018-11-22',
#     'tmin': 33,
#     'tmax': 50,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2018-11-28',
#     'tmin': 25,
#     'tmax': 42,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2018-11-01',
#     'tmin': 55,
#     'tmax': 75,
#     'prcp': 0.11,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.29},
#    {'date': '2018-11-02',
#     'tmin': 60,
#     'tmax': 70,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 11.86},
#    {'date': '2018-11-04',
#     'tmin': 37,
#     'tmax': 65,
#     'prcp': 0.04,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38},
#    {'date': '2018-11-14',
#     'tmin': 39,
#     'tmax': 48,
#     'prcp': 0.04,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2018-11-21',
#     'tmin': 30,
#     'tmax': 57,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.24},
#    {'date': '2018-11-25',
#     'tmin': 42,
#     'tmax': 59,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2018-11-27',
#     'tmin': 31,
#     'tmax': 48,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2018-11-05',
#     'tmin': 54,
#     'tmax': 62,
#     'prcp': 0.82,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2018-11-06',
#     'tmin': 57,
#     'tmax': 74,
#     'prcp': 0.03,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.38},
#    {'date': '2018-11-10',
#     'tmin': 34,
#     'tmax': 52,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.26},
#    {'date': '2018-11-24',
#     'tmin': 36,
#     'tmax': 45,
#     'prcp': 0.72,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2018-11-29',
#     'tmin': 25,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.13}],
#   12: [{'date': '2018-12-21',
#     'tmin': 46,
#     'tmax': 65,
#     'prcp': 0.04,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 14.99},
#    {'date': '2018-12-24',
#     'tmin': 29,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2018-12-27',
#     'tmin': 29,
#     'tmax': 54,
#     'prcp': 0.02,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2018-12-31',
#     'tmin': 47,
#     'tmax': 67,
#     'prcp': 0.13,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.05},
#    {'date': '2018-12-04',
#     'tmin': 41,
#     'tmax': 53,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2018-12-06',
#     'tmin': 25,
#     'tmax': 46,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.8},
#    {'date': '2018-12-18',
#     'tmin': 34,
#     'tmax': 53,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.01},
#    {'date': '2018-12-28',
#     'tmin': 50,
#     'tmax': 68,
#     'prcp': 1.61,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 9.84},
#    {'date': '2018-12-03',
#     'tmin': 47,
#     'tmax': 68,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.59},
#    {'date': '2018-12-08',
#     'tmin': 31,
#     'tmax': 43,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.7},
#    {'date': '2018-12-11',
#     'tmin': 27,
#     'tmax': 44,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 2.0,
#     'awnd': 3.8},
#    {'date': '2018-12-12',
#     'tmin': 24,
#     'tmax': 45,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 1.2,
#     'awnd': 1.34},
#    {'date': '2018-12-13',
#     'tmin': 29,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.24},
#    {'date': '2018-12-23',
#     'tmin': 28,
#     'tmax': 57,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2018-12-29',
#     'tmin': 45,
#     'tmax': 65,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.36},
#    {'date': '2018-12-01',
#     'tmin': 52,
#     'tmax': 62,
#     'prcp': 0.32,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2018-12-05',
#     'tmin': 30,
#     'tmax': 48,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 4.03},
#    {'date': '2018-12-07',
#     'tmin': 29,
#     'tmax': 50,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.79},
#    {'date': '2018-12-09',
#     'tmin': 30,
#     'tmax': 38,
#     'prcp': 1.75,
#     'snow': 7.0,
#     'snwd': 3.1,
#     'awnd': 15.21},
#    {'date': '2018-12-14',
#     'tmin': 36,
#     'tmax': 57,
#     'prcp': 0.7,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.14},
#    {'date': '2018-12-15',
#     'tmin': 42,
#     'tmax': 49,
#     'prcp': 0.23,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 3.58},
#    {'date': '2018-12-16',
#     'tmin': 42,
#     'tmax': 60,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 7.61},
#    {'date': '2018-12-19',
#     'tmin': 27,
#     'tmax': 53,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.12},
#    {'date': '2018-12-25',
#     'tmin': 26,
#     'tmax': 50,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 1.57},
#    {'date': '2018-12-26',
#     'tmin': 26,
#     'tmax': 51,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.46},
#    {'date': '2018-12-02',
#     'tmin': 58,
#     'tmax': 71,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 10.96},
#    {'date': '2018-12-10',
#     'tmin': 30,
#     'tmax': 34,
#     'prcp': 0.73,
#     'snow': 1.9,
#     'snwd': 1.2,
#     'awnd': 7.61},
#    {'date': '2018-12-17',
#     'tmin': 36,
#     'tmax': 61,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 5.82},
#    {'date': '2018-12-20',
#     'tmin': 45,
#     'tmax': 66,
#     'prcp': 0.68,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 8.72},
#    {'date': '2018-12-22',
#     'tmin': 34,
#     'tmax': 53,
#     'prcp': 0.0,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 6.71},
#    {'date': '2018-12-30',
#     'tmin': 45,
#     'tmax': 59,
#     'prcp': 0.01,
#     'snow': 0.0,
#     'snwd': 0.0,
#     'awnd': 2.91}]}}

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

MONTHS = np.array([calendar.month_abbr[m] for m in (np.arange(12) + 1)])

# %%
MONTHS
# Out:
# array(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec'], dtype='<U3')

# %%
j = temps_by_month_for_year(2018)
j
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13864/2707696697.py in <module>
# ----> 1 j = temps_by_month_for_year(2018)
#       2 j
#
# ~\AppData\Local\Temp/ipykernel_13864/2407176050.py in temps_by_month_for_year(year)
#      77 #     the_weather = dict(zip(sorted(the_weather.keys()), [[day['temperaturemax'] for day in the_weather[month]]  for month in sorted(the_weather.keys())]))
#      78     for key in the_weather.keys():
# ---> 79         if len(the_weather[key] < 31):
#      80             the_weather[key]
#      81
#
# TypeError: '<' not supported between instances of 'list' and 'int'
