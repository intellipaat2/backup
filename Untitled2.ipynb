# %%
import pandas as pd

# %%
df = pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# def update_grade(grade, sqft_lot15):

#     for i in range(len(sqft_lot15)):
#         if sqft_lot15[i] > 0 and sqft_lot15[i] <= 400:
#             grade[i] = grade[i] + 1
#         elif sqft_lot15[i] > 400 :
#             grade[i] = grade[i] + 2

#         for i in sqft_lot15:
#         if sqft_lot15 > 0 and sqft_lot15 <= 400:
#             grade = grade + 1
#         elif sqft_lot15 > 400 :
#             grade = grade + 2

# %%
j = list(df['grade'])
j
# Out:
# [7,
#  7,
#  6,
#  7,
#  8,
#  11,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  9,
#  7,
#  7,
#  7,
#  7,
#  7,
#  9,
#  8,
#  7,
#  8,
#  6,
#  8,
#  8,
#  7,
#  8,
#  8,
#  7,
#  7,
#  8,
#  7,
#  8,
#  5,
#  8,
#  7,
#  8,
#  9,
#  8,
#  9,
#  7,
#  6,
#  8,
#  6,
#  9,
#  7,
#  9,
#  7,
#  8,
#  7,
#  7,
#  8,
#  9,
#  7,
#  8,
#  8,
#  8,
#  8,
#  7,
#  8,
#  8,
#  7,
#  7,
#  10,
#  7,
#  7,
#  8,
#  11,
#  7,
#  7,
#  8,
#  7,
#  10,
#  7,
#  7,
#  7,
#  10,
#  8,
#  7,
#  7,
#  8,
#  6,
#  9,
#  7,
#  9,
#  7,
#  7,
#  7,
#  10,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  9,
#  9,
#  7,
#  8,
#  8,
#  7,
#  8,
#  7,
#  8,
#  10,
#  7,
#  8,
#  6,
#  7,
#  7,
#  9,
#  8,
#  8,
#  6,
#  6,
#  7,
#  8,
#  7,
#  6,
#  7,
#  9,
#  8,
#  8,
#  8,
#  7,
#  7,
#  7,
#  8,
#  9,
#  8,
#  9,
#  7,
#  7,
#  8,
#  6,
#  8,
#  7,
#  8,
#  7,
#  7,
#  8,
#  9,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  12,
#  7,
#  7,
#  9,
#  8,
#  7,
#  8,
#  7,
#  7,
#  10,
#  7,
#  7,
# ...

# %%
# def upda():
#     temp =  list(df['sqft_lot15'])
#     grade = list(df['grade'])
#     for i in range(len(temp)):
#         if temp[i] > 0 and temp[i] <= 400:
#             grade[i] = grade[i] + 1
#         elif temp[i] > 400 :
#             grade[i] = grade[i] + 2

#     df['grade'] = grade


def update3(val):
#     if val > 0 and val <= 400:
#     return datagrade = grade[i] + 1

    if val[0] > 400 :
        return int(val[1] + 1)

# %%
df['grade3'] = df[['sqft_lot15', 'grade']].apply(update3)

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df['grade']                                              #.isna().sum()
# Out:
# 0        7
# 1        7
# 2        6
# 3        7
# 4        8
#         ..
# 21608    8
# 21609    8
# 21610    7
# 21611    8
# 21612    7
# Name: grade, Length: 21613, dtype: int64

# %%
def update2(self):
    df['grade'][0] += 1
#     for i in list(df.index):
#         if df['sqft_lot15'][i] > 400:
#             df['grade'][i] += 1

# %%
# df.apply(update2, axis = 0)
df['grade'].apply(update2)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_19304/225310487.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['grade'][0] += 1
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 21608    None
# 21609    None
# 21610    None
# 21611    None
# 21612    None
# Name: grade, Length: 21613, dtype: object

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# df.apply(upda())

# %%
# df['grade'] = df.apply(update_grade(df['grade'], df['sqft_lot15']))

# %%
grad = list(df['grade'])
grad[0] = grad[0] +1
grad
# Out:
# [21621,
#  7,
#  6,
#  7,
#  8,
#  11,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  9,
#  7,
#  7,
#  7,
#  7,
#  7,
#  9,
#  8,
#  7,
#  8,
#  6,
#  8,
#  8,
#  7,
#  8,
#  8,
#  7,
#  7,
#  8,
#  7,
#  8,
#  5,
#  8,
#  7,
#  8,
#  9,
#  8,
#  9,
#  7,
#  6,
#  8,
#  6,
#  9,
#  7,
#  9,
#  7,
#  8,
#  7,
#  7,
#  8,
#  9,
#  7,
#  8,
#  8,
#  8,
#  8,
#  7,
#  8,
#  8,
#  7,
#  7,
#  10,
#  7,
#  7,
#  8,
#  11,
#  7,
#  7,
#  8,
#  7,
#  10,
#  7,
#  7,
#  7,
#  10,
#  8,
#  7,
#  7,
#  8,
#  6,
#  9,
#  7,
#  9,
#  7,
#  7,
#  7,
#  10,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  9,
#  9,
#  7,
#  8,
#  8,
#  7,
#  8,
#  7,
#  8,
#  10,
#  7,
#  8,
#  6,
#  7,
#  7,
#  9,
#  8,
#  8,
#  6,
#  6,
#  7,
#  8,
#  7,
#  6,
#  7,
#  9,
#  8,
#  8,
#  8,
#  7,
#  7,
#  7,
#  8,
#  9,
#  8,
#  9,
#  7,
#  7,
#  8,
#  6,
#  8,
#  7,
#  8,
#  7,
#  7,
#  8,
#  9,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  12,
#  7,
#  7,
#  9,
#  8,
#  7,
#  8,
#  7,
#  7,
#  10,
#  7,
# ...

# %%
df['grade'] = grad
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
temp =  list(df['sqft_lot15'])
grade = list(df['grade'])
for i in range(len(temp)):
    if temp[i] > 0 and temp[i] <= 400:
        grade[i] = grade[i] + 1
    elif temp[i] > 400 :
        grade[i] = grade[i] + 2

df['grade'] = grade

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...
