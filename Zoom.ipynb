# %%
import jwt
import datetime
import requests
import json

# %%
import jwt
import requests
import json
from time import time

API_KEY = '0bGGOjkGS4KS1QJAoWC3TQ'
API_SEC = 'yS85DtxubMiQ1YEOmqFVdCnYJ9ScalrcOkRm'

#optional
# meetingId = 83781439159

# userId = 'getusers()'

# create a function to generate a token using the pyjwt library
def generateToken():
    token = jwt.encode(
        # Create a payload of the token containing API Key & expiration time
        {'iss': API_KEY, 'exp': time() + 5000},
        # Secret used to generate token signature
        API_SEC,
        # Specify the hashing alg
        algorithm='HS256'
        # Convert token to utf-8
    )
    return token
    # send a request with headers including a token

#fetching zoom meeting info
def getUsers():
    headers = {'authorization': 'Bearer %s' % generateToken(),
               'content-type': 'application/json'}

    r = requests.get('https://api.zoom.us/v2/users/', headers=headers)
    print("\n fetching zoom meeting info now of the user ... \n")
    print(r.text)


#fetching zoom meeting participants of the live meeting

def getMeetingParticipants():
    headers = {'authorization': 'Bearer %s' % generateToken(),
               'content-type': 'application/json'}
    r = requests.get(
        f'https://api.zoom.us/v2/metrics/meetings/{meetingId}/participants', headers=headers)
    print("\n fetching zoom meeting participants of the live meeting ... \n")

    # need zoom premium subscription to get this detail
    print(r.text)


# json data that we need to fill as per our requirement for zoom meeting, documentation link below
# https://marketplace.zoom.us/docs/api-reference/zoom-api/meetings/meetingcreate


meetingdetails = {"topic": "The title of your zoom meeting",
                  "type": 2,
                  "start_time": "2019-06-14T10: 21: 57",
                  "duration": "45",
                  "timezone": "Europe/Madrid",
                  "agenda": "test",

                  "recurrence": {"type": 1,
                                 "repeat_interval": 1
                                 },
                  "settings": {"host_video": "true",
                               "participant_video": "true",
                               "join_before_host": "False",
                               "mute_upon_entry": "False",
                               "watermark": "true",
                               "audio": "voip",
                               "auto_recording": "cloud"
                               }
                  }

def createMeeting():
    headers = {'authorization': 'Bearer %s' % generateToken(),
               'content-type': 'application/json'}
    r = requests.post(
        f'https://api.zoom.us/v2/users/meetings', headers=headers, data=json.dumps(meetingdetails))

    print("\n creating zoom meeting ... \n")
    print(r.text)

getUsers()
# getMeetingParticipants()
createMeeting()

###################################
# hire me pls ;(
###################################
# Out:
#  fetching zoom meeting info now of the user ...
#
# {"page_count":1,"page_number":1,"page_size":30,"total_records":1,"next_page_token":"","users":[{"id":"JYcTGu5mRzWUdSEW4LL_nQ","first_name":"Jagveer","last_name":"Yadav","email":"jagveer.intellipaat@gmail.com","type":1,"pmi":6088097589,"timezone":"Asia/Calcutta","verified":1,"created_at":"2022-05-17T05:51:27Z","last_login_time":"2022-05-17T05:51:28Z","language":"en-US","phone_number":"","status":"active","role_id":"0"}]}
#
#  creating zoom meeting ...
#
# <!doctype html>
#
# <html xmlns:fb="http://ogp.me/ns/fb#" lang="en-US">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# zoomvideocall: http://ogp.me/ns/fb/zoomvideocall#">
# <script nonce="HK7Vyx6pTY6oYpFotJs0jQ">
# window.zmGlobalMrktId = "ed444df3b54445f7bebbccfe0fd1eaec" || null;
# window.zmGlobalMrktKey = "" || null;
# </script><title>Error - Zoom</title>
# <meta http-equiv="X-UA-Compatible" content="IE=edge,Chrome=1">
# ...

# %%
# Enter your API key and your API secret
API_KEY = '0bGGOjkGS4KS1QJAoWC3TQ'
API_SEC = 'yS85DtxubMiQ1YEOmqFVdCnYJ9ScalrcOkRm'

# create a function to generate a token
# using the pyjwt library


def generateToken():
    token = jwt.encode(

# Create a payload of the token containing
# API Key & expiration time
    {'iss': API_KEY, 'exp': time() + 5000},

# Secret used to generate token signature
    API_SEC,

# Specify the hashing alg
    algorithm='HS256'
    )
    return token                                          # .decode('utf-8')


# create json data for post requests
meetingdetails = {"topic": "The title of your zoom meeting",
                "type": 2,
                "start_time": "2022-05-17T00:17:00",
                "duration": "45",
                "timezone": "India/Kolkata",
                "agenda": "test",

                "recurrence": {"type": 1,
                                "repeat_interval": 1
                                },
                "settings": {"host_video": "true",
                            "participant_video": "true",
                            "join_before_host": "False",
                            "mute_upon_entry": "False",
                            "watermark": "true",
                            "audio": "voip",
                            "auto_recording": "cloud"
                            }
                }

# send a request with headers including
# a token and meeting details


def createMeeting():
    headers = {'authorization': 'Bearer ' + generateToken(),
            'content-type': 'application/json'}
    r = requests.post(
        f'https://api.zoom.us/v2/users/me/meetings',
        headers=headers, data=json.dumps(meetingdetails))

    print("\n creating zoom meeting ... \n")
    # print(r.text)
    # converting the output into json and extracting the details
    y = json.loads(r.text)
    join_URL = y["join_url"]
    meetingPassword = y["password"]

    print(f'\nHere is your zoom meeting link {join_URL} and your \npassword: "{meetingPassword}"\n')


# run the create meeting function
createMeeting()
# Out:
#  creating zoom meeting ...
#
#
# Here is your zoom meeting link https://us05web.zoom.us/j/84140651157?pwd=U0JuZEhqVXhNblREWS8zNEpCbnlMUT09 and your
# password: "V4tWFj"
